# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from sklearn.cross_validation import train_test_split



dataset=np.loadtxt("50logis_data1000_d2_v3.csv", delimiter=",")
#contem 1000 conjuntos de 3 valores xn-2 a xn

label=np.loadtxt("50logis_lab_data1000_d2_v3.csv", delimiter=",")
#contem a classe do xn+50 correspondente a cada conjunto: 0 se <0.5 e 1 se >0.5

dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=1)

file= open("50results_logis_data1000_d2_v3.csv","w+")
#guarda as acurácias obtidas pelas redes


def one_hot_encode_object_array(arr):
    '''One hot encode a numpy array of objects (e.g. strings)'''
    uniques, ids = np.unique(arr, return_inverse=True)
    return np_utils.to_categorical(ids, len(uniques))
ltrain=one_hot_encode_object_array(ltrain)
ltest=one_hot_encode_object_array(ltest)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
n1=1

file.write('adam 0.1 \n')

while n1<=40:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(3,), activation='relu'))
    model.add(Dense(2, activation='softmax'))

    model.summary()

    adam=keras.optimizers.Adam(lr=0.1)

    model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])


    print("1 hidden layer:", n1,"\n")


    model.fit(dtrain, ltrain, epochs=300, batch_size=10)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
        
    n1+=1
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 4
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 4
# ...
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________
# 1 hidden layer: 1
#
# Epoch 1/300
# 700/700 [==============================] - 0s 554us/step - loss: 0.6139 - acc: 0.7136
# Epoch 2/300
# 700/700 [==============================] - 0s 139us/step - loss: 0.6068 - acc: 0.7157
# Epoch 3/300
# 700/700 [==============================] - 0s 168us/step - loss: 0.6010 - acc: 0.7157
# Epoch 4/300
# 700/700 [==============================] - 0s 149us/step - loss: 0.6069 - acc: 0.7157
# Epoch 5/300
# 700/700 [==============================] - 0s 184us/step - loss: 0.6028 - acc: 0.7157
# Epoch 6/300
# ...

# %%
n1=1

file.write('adam\n')

while n1<=40:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(3,), activation='relu'))
    model.add(Dense(2, activation='softmax'))

    model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])


    print("1 hidden layer:", n1,"\n")


    model.fit(dtrain, ltrain, epochs=300, batch_size=10)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
        
    n1+=1
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_81 (Dense)             (None, 1)                 4
# _________________________________________________________________
# dense_82 (Dense)             (None, 2)                 4
# ...
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________
# 1 hidden layer: 1
#
# Epoch 1/300
# 700/700 [==============================] - 2s 2ms/step - loss: 0.6538 - acc: 0.7093
# Epoch 2/300
# 700/700 [==============================] - 0s 190us/step - loss: 0.6290 - acc: 0.7157
# Epoch 3/300
# 700/700 [==============================] - 0s 192us/step - loss: 0.6144 - acc: 0.7157
# Epoch 4/300
# 700/700 [==============================] - 0s 197us/step - loss: 0.6069 - acc: 0.7157
# Epoch 5/300
# 700/700 [==============================] - 0s 173us/step - loss: 0.6041 - acc: 0.7157
# Epoch 6/300
# ...

# %%
n1=1000

while n1<=1001:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(3,), activation='relu'))
    model.add(Dense(2, activation='softmax'))

    model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])


    print("1 hidden layer:", n1,"\n")


    model.fit(dtrain, ltrain, epochs=300, batch_size=10)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
        
    n1+=1
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_161 (Dense)            (None, 1000)              4000
# _________________________________________________________________
# dense_162 (Dense)            (None, 2)                 2002
# ...
# Total params: 6,002
# Trainable params: 6,002
# Non-trainable params: 0
# _________________________________________________________________
# 1 hidden layer: 1000
#
# Epoch 1/300
# 700/700 [==============================] - 3s 4ms/step - loss: 0.6098 - acc: 0.7100
# Epoch 2/300
# 700/700 [==============================] - 0s 252us/step - loss: 0.5974 - acc: 0.7157
# Epoch 3/300
# 700/700 [==============================] - 0s 257us/step - loss: 0.5924 - acc: 0.7157
# Epoch 4/300
# 700/700 [==============================] - 0s 259us/step - loss: 0.5931 - acc: 0.7157
# Epoch 5/300
# 700/700 [==============================] - 0s 220us/step - loss: 0.5937 - acc: 0.7157
# ...

# %%
file.close()
