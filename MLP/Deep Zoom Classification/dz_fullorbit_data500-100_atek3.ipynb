# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz_fullorbit_data500-100_atek4.csv", delimiter=",")

data2=[]
for i in range(data.shape[0]):
    if data[i][100]!=4:
        data2.append(data[i])

data3=np.asarray(data2)
dataset=data3[:,0:100].copy()
label=data3[:,100:101].copy()
    

dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_fullorbit_data500-100_atek3_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(100,), activation='relu'))
    model.add(Dense(4, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom full orbit até k=3, 500-100, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom full orbit até k=3, 500-100, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1','2','3']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 1200/1200 [==============================] - 0s 70us/step
# 2800/2800 [==============================] - 0s 33us/step
# 0.890945603052775 54.33
# Normalized confusion matrix
# [[0.99669967 0.         0.         0.00330033]
#  [0.         0.63461538 0.19871795 0.16666667]
#  [0.0070922  0.4822695  0.22695035 0.28368794]
#  [0.00330033 0.48184818 0.22442244 0.29042904]]
# Nº neurônios: 10
#
# 1200/1200 [==============================] - 0s 129us/step
# 2800/2800 [==============================] - 0s 51us/step
# 1.2701516485214233 48.58
# Normalized confusion matrix
# [[0.97689769 0.         0.02310231 0.        ]
#  [0.00320513 0.26602564 0.375      0.35576923]
#  [0.0212766  0.19503546 0.36524823 0.41843972]
#  [0.01980198 0.21122112 0.43564356 0.33333333]]
# Nº neurônios: 15
#
# 1200/1200 [==============================] - 0s 201us/step
# 2800/2800 [==============================] - 0s 66us/step
# 1.8111035696665445 50.67
# Normalized confusion matrix
# [[0.9669967  0.         0.00990099 0.02310231]
#  [0.01282051 0.35897436 0.3525641  0.27564103]
#  [0.0141844  0.24822695 0.38652482 0.35106383]
#  [0.03630363 0.27392739 0.37953795 0.31023102]]
# Nº neurônios: 20
#
# 1200/1200 [==============================] - 0s 250us/step
# 2800/2800 [==============================] - 0s 71us/step
# 1.7172075684865316 50.0
# Normalized confusion matrix
# [[0.98019802 0.01980198 0.         0.        ]
#  [0.00641026 0.47115385 0.2724359  0.25      ]
#  [0.02836879 0.41134752 0.28723404 0.27304965]
#  [0.02310231 0.3960396  0.33333333 0.24752475]]
# Nº neurônios: 25
#
# 1200/1200 [==============================] - 0s 93us/step
# 2800/2800 [==============================] - 0s 32us/step
# 2.7420411777496336 49.83
# Normalized confusion matrix
# [[0.97689769 0.00660066 0.00330033 0.01320132]
#  [0.01923077 0.38782051 0.30128205 0.29166667]
#  [0.0070922  0.37943262 0.35106383 0.26241135]
#  [0.01320132 0.38283828 0.33333333 0.27062706]]
# Nº neurônios: 30
#
# 1200/1200 [==============================] - 0s 107us/step
# 2800/2800 [==============================] - 0s 33us/step
# 3.3743521404266357 50.0
# Normalized confusion matrix
# [[0.98679868 0.         0.00990099 0.00330033]
#  [0.00641026 0.30128205 0.41666667 0.27564103]
#  [0.0141844  0.23049645 0.38652482 0.36879433]
#  [0.02640264 0.24752475 0.40264026 0.32343234]]
# Nº neurônios: 35
#
# 1200/1200 [==============================] - 0s 113us/step
# 2800/2800 [==============================] - 0s 33us/step
# 4.026155563990275 49.83
# Normalized confusion matrix
# [[0.98019802 0.         0.00660066 0.01320132]
#  [0.0224359  0.44230769 0.25320513 0.28205128]
#  [0.0141844  0.41134752 0.28723404 0.28723404]
#  [0.02640264 0.41254125 0.29042904 0.27062706]]
# Nº neurônios: 40
#
# 1200/1200 [==============================] - 0s 120us/step
# 2800/2800 [==============================] - 0s 33us/step
# 4.0035154263178505 48.25
# Normalized confusion matrix
# [[0.98349835 0.         0.00660066 0.00990099]
#  [0.00641026 0.30769231 0.34294872 0.34294872]
#  [0.0141844  0.24468085 0.32624113 0.41489362]
#  [0.00990099 0.24752475 0.43564356 0.30693069]]
# Nº neurônios: 45
#
# 1200/1200 [==============================] - 0s 129us/step
# 2800/2800 [==============================] - 0s 33us/step
# 3.839079802831014 53.92
# Normalized confusion matrix
# [[0.98019802 0.00660066 0.00990099 0.00330033]
#  [0.01282051 0.44551282 0.24358974 0.29807692]
#  [0.0248227  0.28014184 0.35815603 0.33687943]
#  [0.01320132 0.32343234 0.30033003 0.3630363 ]]
# Nº neurônios: 50
#
# 1200/1200 [==============================] - 0s 135us/step
# 2800/2800 [==============================] - 0s 34us/step
# 3.9281846300760903 51.92
# Normalized confusion matrix
# [[0.99009901 0.         0.00990099 0.        ]
#  [0.00320513 0.37179487 0.34935897 0.27564103]
#  [0.0106383  0.27659574 0.37943262 0.33333333]
#  [0.01320132 0.31023102 0.34653465 0.330033  ]]
# Nº neurônios: 60
#
# 1200/1200 [==============================] - 0s 149us/step
# 2800/2800 [==============================] - 0s 33us/step
# 4.150309155782064 51.75
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.40064103 0.32371795 0.27564103]
#  [0.0035461  0.30851064 0.33687943 0.35106383]
#  [0.01320132 0.32673267 0.33663366 0.32343234]]
# Nº neurônios: 70
#
# 1200/1200 [==============================] - 0s 158us/step
# 2800/2800 [==============================] - 0s 43us/step
# 4.104525492986043 50.67
# Normalized confusion matrix
# [[0.99669967 0.         0.         0.00330033]
#  [0.00320513 0.39423077 0.33333333 0.26923077]
#  [0.0141844  0.27659574 0.32624113 0.38297872]
#  [0.00660066 0.35643564 0.33663366 0.30033003]]
# Nº neurônios: 80
#
# 1200/1200 [==============================] - 0s 165us/step
# 2800/2800 [==============================] - 0s 33us/step
# 4.062410036722819 50.5
# Normalized confusion matrix
# [[0.99669967 0.         0.00330033 0.        ]
#  [0.00320513 0.35897436 0.3525641  0.28525641]
#  [0.0070922  0.31205674 0.30496454 0.37588652]
#  [0.00990099 0.30033003 0.33993399 0.34983498]]
# Nº neurônios: 90
#
# 1200/1200 [==============================] - 0s 184us/step
# 2800/2800 [==============================] - 0s 35us/step
# 3.9506036376953126 49.75
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00961538 0.38782051 0.37179487 0.23076923]
#  [0.0141844  0.37943262 0.34751773 0.25886525]
#  [0.00660066 0.35973597 0.38613861 0.24752475]]
# Nº neurônios: 100
#
# 1200/1200 [==============================] - 0s 187us/step
# 2800/2800 [==============================] - 0s 36us/step
# 3.9095663452148437 51.75
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.41025641 0.34615385 0.24038462]
#  [0.0035461  0.28723404 0.34751773 0.36170213]
#  [0.         0.30693069 0.38943894 0.30363036]]
# Nº neurônios: 200
#
# 1200/1200 [==============================] - 0s 198us/step
# 2800/2800 [==============================] - 0s 37us/step
# 3.3686897881825764 52.08
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.41025641 0.31089744 0.27564103]
#  [0.0106383  0.29787234 0.36879433 0.32269504]
#  [0.01320132 0.32343234 0.36633663 0.2970297 ]]
# Nº neurônios: 300
#
# 1200/1200 [==============================] - 0s 211us/step
# 2800/2800 [==============================] - 0s 38us/step
# 3.322332550684611 51.17
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.40064103 0.32692308 0.26923077]
#  [0.0035461  0.33333333 0.28723404 0.37588652]
#  [0.00330033 0.33333333 0.31683168 0.34653465]]
# Nº neurônios: 400
#
# 1200/1200 [==============================] - 0s 249us/step
# 2800/2800 [==============================] - 0s 41us/step
# 3.5606591924031576 49.83
# Normalized confusion matrix
# [[0.99669967 0.         0.00330033 0.        ]
#  [0.         0.34615385 0.45192308 0.20192308]
#  [0.0106383  0.27659574 0.40780142 0.30496454]
#  [0.00660066 0.31023102 0.44224422 0.24092409]]
# Nº neurônios: 500
#
# 1200/1200 [==============================] - 0s 238us/step
# 2800/2800 [==============================] - 0s 42us/step
# 3.243923152287801 50.83
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.37179487 0.31730769 0.31089744]
#  [0.0141844  0.30851064 0.33333333 0.34397163]
#  [0.00990099 0.31353135 0.35643564 0.32013201]]
# Nº neurônios: 600
#
# 1200/1200 [==============================] - 0s 262us/step
# 2800/2800 [==============================] - 0s 44us/step
# 3.4249161672592163 50.83
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.40064103 0.33653846 0.25961538]
#  [0.0106383  0.35815603 0.30141844 0.32978723]
#  [0.00990099 0.32013201 0.34983498 0.32013201]]
# Nº neurônios: 700
#
# 1200/1200 [==============================] - 0s 262us/step
# 2800/2800 [==============================] - 0s 47us/step
# 3.2909082794189453 51.67
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.41025641 0.29807692 0.28846154]
#  [0.0141844  0.29078014 0.34751773 0.34751773]
#  [0.01320132 0.31683168 0.36963696 0.30033003]]
# Nº neurônios: 800
#
# 1200/1200 [==============================] - 0s 274us/step
# 2800/2800 [==============================] - 0s 47us/step
# 2.904696154594421 51.75
# Normalized confusion matrix
# [[0.99669967 0.00330033 0.         0.        ]
#  [0.01282051 0.375      0.31730769 0.29487179]
#  [0.0141844  0.31205674 0.32269504 0.35106383]
#  [0.00990099 0.32013201 0.30363036 0.36633663]]
# Nº neurônios: 900
#
# 1200/1200 [==============================] - 0s 288us/step
# 2800/2800 [==============================] - 0s 46us/step
# 3.058886292775472 49.92
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.01602564 0.30769231 0.31089744 0.36538462]
#  [0.0070922  0.26241135 0.30496454 0.42553191]
#  [0.00990099 0.28382838 0.330033   0.37623762]]
# Nº neurônios: 1000
#
# 1200/1200 [==============================] - 0s 306us/step
# 2800/2800 [==============================] - 0s 45us/step
# 3.250508125623067 50.17
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.36217949 0.33333333 0.30448718]
#  [0.0070922  0.27659574 0.36170213 0.35460993]
#  [0.00990099 0.33663366 0.37623762 0.27722772]]

# %%
file.close()

# %%
valores=np.loadtxt("results_fullorbit_data500-100_atek3_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom full orbit até k=3, 500-100, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom full orbit até k=3, 500-100, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()
