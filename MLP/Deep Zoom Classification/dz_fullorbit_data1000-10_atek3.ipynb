# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz_fullorbit_data1000-10_atek4.csv", delimiter=",")

data2=[]
for i in range(data.shape[0]):
    if data[i][10]!=4:
        data2.append(data[i])

data3=np.asarray(data2)
dataset=data3[:,0:10].copy()
label=data3[:,10:11].copy()
    

dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_fullorbit_data1000-10_atek3_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(10,), activation='relu'))
    model.add(Dense(4, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom full orbit até k=3, 1000-10, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom full orbit até k=3, 1000-10, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1','2','3']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 1200/1200 [==============================] - 0s 65us/step
# 2800/2800 [==============================] - 0s 24us/step
# 0.927212282816569 51.75
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.03525641 0.42307692 0.30128205 0.24038462]
#  [0.05319149 0.30141844 0.36170213 0.28368794]
#  [0.04620462 0.36963696 0.30693069 0.27722772]]
# Nº neurônios: 10
#
# 1200/1200 [==============================] - 0s 80us/step
# 2800/2800 [==============================] - 0s 28us/step
# 0.9388946119944255 50.75
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.04807692 0.29807692 0.29166667 0.36217949]
#  [0.03546099 0.19858156 0.33333333 0.43262411]
#  [0.06270627 0.20462046 0.33993399 0.39273927]]
# Nº neurônios: 15
#
# 1200/1200 [==============================] - 0s 117us/step
# 2800/2800 [==============================] - 0s 28us/step
# 0.8865435226758321 52.5
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.03525641 0.40384615 0.30769231 0.25320513]
#  [0.03900709 0.29432624 0.42198582 0.24468085]
#  [0.0330033  0.32673267 0.36963696 0.27062706]]
# Nº neurônios: 20
#
# 1200/1200 [==============================] - 0s 83us/step
# 2800/2800 [==============================] - 0s 27us/step
# 0.9040694363911946 49.83
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.01602564 0.29487179 0.51923077 0.16987179]
#  [0.03546099 0.25531915 0.54964539 0.15957447]
#  [0.01980198 0.25412541 0.56765677 0.15841584]]
# Nº neurônios: 25
#
# 1200/1200 [==============================] - 0s 87us/step
# 2800/2800 [==============================] - 0s 28us/step
# 0.8976244401931762 53.58
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.02564103 0.55448718 0.25641026 0.16346154]
#  [0.03546099 0.39716312 0.39361702 0.17375887]
#  [0.02640264 0.41914191 0.36963696 0.18481848]]
# Nº neurônios: 30
#
# 1200/1200 [==============================] - 0s 95us/step
# 2800/2800 [==============================] - 0s 27us/step
# 0.8720379980405172 52.25
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00641026 0.57692308 0.20512821 0.21153846]
#  [0.0106383  0.4964539  0.28368794 0.20921986]
#  [0.01650165 0.44554455 0.32673267 0.21122112]]
# Nº neurônios: 35
#
# 1200/1200 [==============================] - 0s 117us/step
# 2800/2800 [==============================] - 0s 28us/step
# 0.8708245913187663 52.67
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00961538 0.37179487 0.33012821 0.28846154]
#  [0.0248227  0.20921986 0.45035461 0.31560284]
#  [0.01650165 0.26072607 0.43894389 0.28382838]]
# Nº neurônios: 40
#
# 1200/1200 [==============================] - 0s 117us/step
# 2800/2800 [==============================] - 0s 30us/step
# 0.8639815990130106 54.08
# Normalized confusion matrix
# [[0.99669967 0.00330033 0.         0.        ]
#  [0.01282051 0.50961538 0.23076923 0.24679487]
#  [0.0141844  0.30851064 0.29432624 0.38297872]
#  [0.01320132 0.37953795 0.26072607 0.34653465]]
# Nº neurônios: 45
#
# 1200/1200 [==============================] - 0s 117us/step
# 2800/2800 [==============================] - 0s 32us/step
# 0.8564030583699545 55.08
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.49358974 0.31089744 0.19230769]
#  [0.0106383  0.25177305 0.4893617  0.24822695]
#  [0.00990099 0.30033003 0.47194719 0.21782178]]
# Nº neurônios: 50
#
# 1200/1200 [==============================] - 0s 130us/step
# 2800/2800 [==============================] - 0s 27us/step
# 0.8521562282244365 56.08
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.56730769 0.21153846 0.21794872]
#  [0.0177305  0.30851064 0.36879433 0.30496454]
#  [0.01320132 0.29372937 0.39933993 0.29372937]]
# Nº neurônios: 60
#
# 1200/1200 [==============================] - 0s 161us/step
# 2800/2800 [==============================] - 0s 24us/step
# 0.8573296602567037 54.17
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00641026 0.57371795 0.1474359  0.2724359 ]
#  [0.0177305  0.33333333 0.21631206 0.43262411]
#  [0.00990099 0.3960396  0.24092409 0.35313531]]
# Nº neurônios: 70
#
# 1200/1200 [==============================] - 0s 160us/step
# 2800/2800 [==============================] - 0s 28us/step
# 0.8644880104064941 55.75
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.45833333 0.25       0.28846154]
#  [0.0106383  0.21985816 0.41489362 0.35460993]
#  [0.00990099 0.28712871 0.35313531 0.34983498]]
# Nº neurônios: 80
#
# 1200/1200 [==============================] - 0s 158us/step
# 2800/2800 [==============================] - 0s 45us/step
# 0.8486782383918762 58.25
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.55128205 0.23397436 0.21474359]
#  [0.0141844  0.24113475 0.43971631 0.30496454]
#  [0.00660066 0.23762376 0.42574257 0.330033  ]]
# Nº neurônios: 90
#
# 1200/1200 [==============================] - 0s 177us/step
# 2800/2800 [==============================] - 0s 29us/step
# 0.8332908344268799 57.58
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.57692308 0.25961538 0.16346154]
#  [0.0070922  0.26950355 0.46453901 0.25886525]
#  [0.00330033 0.29372937 0.44884488 0.25412541]]
# Nº neurônios: 100
#
# 1200/1200 [==============================] - 0s 175us/step
# 2800/2800 [==============================] - 0s 31us/step
# 0.8568658518791199 56.92
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00961538 0.56730769 0.27884615 0.14423077]
#  [0.0070922  0.26950355 0.4751773  0.24822695]
#  [0.00990099 0.30693069 0.45544554 0.22772277]]
# Nº neurônios: 200
#
# 1200/1200 [==============================] - 0s 188us/step
# 2800/2800 [==============================] - 0s 33us/step
# 0.9130549303690593 60.25
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.5224359  0.24038462 0.23397436]
#  [0.0035461  0.10992908 0.45390071 0.43262411]
#  [0.00660066 0.14191419 0.42574257 0.42574257]]
# Nº neurônios: 300
#
# 1200/1200 [==============================] - 0s 199us/step
# 2800/2800 [==============================] - 0s 41us/step
# 0.9340198548634847 64.25
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.75320513 0.13141026 0.11217949]
#  [0.0035461  0.24113475 0.46099291 0.29432624]
#  [0.00330033 0.25412541 0.40264026 0.33993399]]
# Nº neurônios: 400
#
# 1200/1200 [==============================] - 0s 206us/step
# 2800/2800 [==============================] - 0s 36us/step
# 1.0327374450365703 63.33
# Normalized confusion matrix
# [[0.99009901 0.00990099 0.         0.        ]
#  [0.00320513 0.75320513 0.15384615 0.08974359]
#  [0.0035461  0.24822695 0.45744681 0.29078014]
#  [0.00660066 0.25742574 0.41914191 0.31683168]]
# Nº neurônios: 500
#
# 1200/1200 [==============================] - 0s 219us/step
# 2800/2800 [==============================] - 0s 34us/step
# 1.1025320386886597 64.33
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00641026 0.67948718 0.17307692 0.14102564]
#  [0.0141844  0.14893617 0.46453901 0.37234043]
#  [0.00660066 0.17491749 0.40264026 0.41584158]]
# Nº neurônios: 600
#
# 1200/1200 [==============================] - 0s 224us/step
# 2800/2800 [==============================] - 0s 35us/step
# 1.1090529998143515 66.42
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.67628205 0.19551282 0.12820513]
#  [0.0035461  0.10283688 0.5177305  0.37588652]
#  [0.00660066 0.1320132  0.40924092 0.45214521]]
# Nº neurônios: 700
#
# 1200/1200 [==============================] - 0s 229us/step
# 2800/2800 [==============================] - 0s 37us/step
# 1.1783931628863016 66.42
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.77564103 0.08012821 0.14423077]
#  [0.0070922  0.16312057 0.35460993 0.4751773 ]
#  [0.00660066 0.22442244 0.26732673 0.50165017]]
# Nº neurônios: 800
#
# 1200/1200 [==============================] - 0s 267us/step
# 2800/2800 [==============================] - 0s 35us/step
# 1.241430451075236 66.08
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.72115385 0.13141026 0.1474359 ]
#  [0.0035461  0.15602837 0.44680851 0.39361702]
#  [0.00660066 0.15841584 0.37623762 0.45874587]]
# Nº neurônios: 900
#
# 1200/1200 [==============================] - 0s 249us/step
# 2800/2800 [==============================] - 0s 33us/step
# 1.2572719065348308 66.33
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.         0.70192308 0.14102564 0.15705128]
#  [0.0070922  0.13120567 0.42198582 0.43971631]
#  [0.00330033 0.14191419 0.34323432 0.51155116]]
# Nº neurônios: 1000
#
# 1200/1200 [==============================] - 0s 262us/step
# 2800/2800 [==============================] - 0s 35us/step
# 1.2729329737027486 65.83
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.76923077 0.08333333 0.14423077]
#  [0.0035461  0.17375887 0.35460993 0.46808511]
#  [0.00660066 0.19141914 0.31683168 0.48514851]]

# %%
file.close()

# %%
valores=np.loadtxt("results_fullorbit_data1000-10_atek3_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom full orbit até k=3, 1000-10, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom full orbit até k=3, 1000-10, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()
