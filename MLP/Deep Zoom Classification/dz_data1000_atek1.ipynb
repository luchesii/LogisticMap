# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz-data1000_atek4.csv", delimiter=",")

data2=[]
for i in range(data.shape[0]):
    if data[i][2]==0 or data[i][2]==1:
        data2.append(data[i])

data3=np.asarray(data2)
dataset=data3[:,0:2].copy()
label=data3[:,2:3].copy()
    
dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_logis_data10000_atek1_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(2,), activation='relu'))
    model.add(Dense(2, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom até k=1, 1000, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom até k=1, 1000, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 600/600 [==============================] - 0s 84us/step
# 1400/1400 [==============================] - 0s 27us/step
# 0.5478761001427969 76.5
# Normalized confusion matrix
# [[0.88039867 0.11960133]
#  [0.35117057 0.64882943]]
# Nº neurônios: 10
#
# 600/600 [==============================] - 0s 110us/step
# 1400/1400 [==============================] - 0s 29us/step
# 0.46725274523099264 78.17
# Normalized confusion matrix
# [[0.87375415 0.12624585]
#  [0.31103679 0.68896321]]
# Nº neurônios: 15
#
# 600/600 [==============================] - 0s 164us/step
# 1400/1400 [==============================] - 0s 35us/step
# 0.3635719724496206 86.33
# Normalized confusion matrix
# [[0.9833887  0.0166113 ]
#  [0.25752508 0.74247492]]
# Nº neurônios: 20
#
# 600/600 [==============================] - 0s 195us/step
# 1400/1400 [==============================] - 0s 36us/step
# 0.5498080476125081 76.0
# Normalized confusion matrix
# [[0.88704319 0.11295681]
#  [0.36789298 0.63210702]]
# Nº neurônios: 25
#
# 600/600 [==============================] - 0s 227us/step
# 1400/1400 [==============================] - 0s 35us/step
# 0.4011846641699473 83.17
# Normalized confusion matrix
# [[0.93355482 0.06644518]
#  [0.27090301 0.72909699]]
# Nº neurônios: 30
#
# 600/600 [==============================] - 0s 294us/step
# 1400/1400 [==============================] - 0s 37us/step
# 0.2854840926329295 91.5
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.17056856 0.82943144]]
# Nº neurônios: 35
#
# 600/600 [==============================] - 0s 284us/step
# 1400/1400 [==============================] - 0s 36us/step
# 0.40237098892529805 85.0
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.30100334 0.69899666]]
# Nº neurônios: 40
#
# 600/600 [==============================] - 0s 297us/step
# 1400/1400 [==============================] - 0s 43us/step
# 0.3566583267847697 86.83
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.26421405 0.73578595]]
# Nº neurônios: 45
#
# 600/600 [==============================] - 0s 338us/step
# 1400/1400 [==============================] - 0s 35us/step
# 0.2516014269987742 90.33
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.19397993 0.80602007]]
# Nº neurônios: 50
#
# 600/600 [==============================] - 0s 372us/step
# 1400/1400 [==============================] - 0s 37us/step
# 0.2765342859427134 90.5
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.19063545 0.80936455]]
# Nº neurônios: 60
#
# 600/600 [==============================] - 0s 463us/step
# 1400/1400 [==============================] - 0s 46us/step
# 0.2518497184912364 90.33
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.19397993 0.80602007]]
# Nº neurônios: 70
#
# 600/600 [==============================] - 0s 405us/step
# 1400/1400 [==============================] - 0s 34us/step
# 0.24192959507306416 90.67
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.18729097 0.81270903]]
# Nº neurônios: 80
#
# 600/600 [==============================] - 0s 485us/step
# 1400/1400 [==============================] - 0s 42us/step
# 0.24169567664464314 90.17
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.19732441 0.80267559]]
# Nº neurônios: 90
#
# 600/600 [==============================] - 0s 465us/step
# 1400/1400 [==============================] - 0s 37us/step
# 0.22627795318762461 93.33
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.13377926 0.86622074]]
# Nº neurônios: 100
#
# 600/600 [==============================] - 0s 509us/step
# 1400/1400 [==============================] - 0s 36us/step
# 0.22733864585558575 91.0
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.18060201 0.81939799]]
# Nº neurônios: 200
#
# 600/600 [==============================] - 0s 551us/step
# 1400/1400 [==============================] - 0s 42us/step
# 0.19772514641284944 93.33
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.13377926 0.86622074]]
# Nº neurônios: 300
#
# 600/600 [==============================] - 0s 497us/step
# 1400/1400 [==============================] - 0s 36us/step
# 0.19818537890911103 94.67
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.10702341 0.89297659]]
# Nº neurônios: 400
#
# 600/600 [==============================] - 0s 566us/step
# 1400/1400 [==============================] - 0s 37us/step
# 0.21397565364837645 92.17
# Normalized confusion matrix
# [[0.95681063 0.04318937]
#  [0.11371237 0.88628763]]
# Nº neurônios: 500
#
# 600/600 [==============================] - 0s 583us/step
# 1400/1400 [==============================] - 0s 40us/step
# 0.19360205312569936 94.67
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.10702341 0.89297659]]
# Nº neurônios: 600
#
# 600/600 [==============================] - 0s 808us/step
# 1400/1400 [==============================] - 0s 54us/step
# 0.1895234042406082 94.0
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.12040134 0.87959866]]
# Nº neurônios: 700
#
# 600/600 [==============================] - 0s 641us/step
# 1400/1400 [==============================] - 0s 46us/step
# 0.1899003634850184 94.5
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.11036789 0.88963211]]
# Nº neurônios: 800
#
# 600/600 [==============================] - 0s 763us/step
# 1400/1400 [==============================] - 0s 49us/step
# 0.19915535549322763 93.17
# Normalized confusion matrix
# [[0.96013289 0.03986711]
#  [0.09698997 0.90301003]]
# Nº neurônios: 900
#
# 600/600 [==============================] - 0s 700us/step
# 1400/1400 [==============================] - 0s 46us/step
# 0.17114399174849193 94.33
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.11371237 0.88628763]]
# Nº neurônios: 1000
#
# 600/600 [==============================] - 0s 737us/step
# 1400/1400 [==============================] - 0s 50us/step
# 0.18244537075360617 93.83
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.12374582 0.87625418]]

# %%
file.close()

# %%
import numpy as np
import matplotlib.pyplot as plt 

valores=np.loadtxt("results_logis_data10000_atek1_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom até k=1, 1000, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom até k=1, 1000, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()

# %% [markdown]
# #
