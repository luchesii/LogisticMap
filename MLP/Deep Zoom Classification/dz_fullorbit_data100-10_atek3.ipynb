# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz_fullorbit_data100-10_atek4.csv", delimiter=",")

data2=[]
for i in range(data.shape[0]):
    if data[i][10]!=4:
        data2.append(data[i])

data3=np.asarray(data2)
dataset=data3[:,0:10].copy()
label=data3[:,10:11].copy()
    

dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_fullorbit_data100-10_atek3_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(10,), activation='relu'))
    model.add(Dense(4, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom full orbit até k=3, 100-10, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom full orbit até k=3, 100-10, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1','2','3']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 120/120 [==============================] - 0s 384us/step
# 280/280 [==============================] - 0s 22us/step
# 1.1353444417317708 47.5
# Normalized confusion matrix
# [[0.85294118 0.         0.08823529 0.05882353]
#  [0.15151515 0.36363636 0.3030303  0.18181818]
#  [0.22222222 0.18518519 0.33333333 0.25925926]
#  [0.03846154 0.23076923 0.46153846 0.26923077]]
# Nº neurônios: 10
#
# 120/120 [==============================] - 0s 363us/step
# 280/280 [==============================] - 0s 29us/step
# 1.0827067375183106 45.83
# Normalized confusion matrix
# [[0.85294118 0.         0.11764706 0.02941176]
#  [0.03030303 0.45454545 0.3030303  0.21212121]
#  [0.18518519 0.25925926 0.2962963  0.25925926]
#  [0.03846154 0.46153846 0.38461538 0.11538462]]
# Nº neurônios: 15
#
# 120/120 [==============================] - 0s 744us/step
# 280/280 [==============================] - 0s 57us/step
# 1.1060853083928426 45.83
# Normalized confusion matrix
# [[0.91176471 0.         0.         0.08823529]
#  [0.06060606 0.33333333 0.36363636 0.24242424]
#  [0.14814815 0.22222222 0.40740741 0.22222222]
#  [0.07692308 0.26923077 0.57692308 0.07692308]]
# Nº neurônios: 20
#
# 120/120 [==============================] - 0s 651us/step
# 280/280 [==============================] - 0s 33us/step
# 1.0689846436182657 50.83
# Normalized confusion matrix
# [[0.91176471 0.         0.         0.08823529]
#  [0.03030303 0.42424242 0.36363636 0.18181818]
#  [0.11111111 0.25925926 0.33333333 0.2962963 ]
#  [0.07692308 0.26923077 0.38461538 0.26923077]]
# Nº neurônios: 25
#
# 120/120 [==============================] - 0s 651us/step
# 280/280 [==============================] - 0s 33us/step
# 1.006462323665619 50.83
# Normalized confusion matrix
# [[0.88235294 0.         0.08823529 0.02941176]
#  [0.06060606 0.36363636 0.33333333 0.24242424]
#  [0.11111111 0.11111111 0.48148148 0.2962963 ]
#  [0.03846154 0.19230769 0.53846154 0.23076923]]
# Nº neurônios: 30
#
# 120/120 [==============================] - 0s 781us/step
# 280/280 [==============================] - 0s 32us/step
# 0.9964400291442871 48.33
# Normalized confusion matrix
# [[0.88235294 0.         0.         0.11764706]
#  [0.03030303 0.36363636 0.39393939 0.21212121]
#  [0.07407407 0.18518519 0.51851852 0.22222222]
#  [0.         0.26923077 0.65384615 0.07692308]]
# Nº neurônios: 35
#
# 120/120 [==============================] - 0s 781us/step
# 280/280 [==============================] - 0s 33us/step
# 1.0105223258336384 50.83
# Normalized confusion matrix
# [[0.88235294 0.         0.02941176 0.08823529]
#  [0.03030303 0.33333333 0.45454545 0.18181818]
#  [0.11111111 0.14814815 0.51851852 0.22222222]
#  [0.         0.30769231 0.46153846 0.23076923]]
# Nº neurônios: 40
#
# 120/120 [==============================] - 0s 912us/step
# 280/280 [==============================] - 0s 43us/step
# 1.077177627881368 45.83
# Normalized confusion matrix
# [[0.85294118 0.02941176 0.05882353 0.05882353]
#  [0.03030303 0.36363636 0.39393939 0.21212121]
#  [0.14814815 0.18518519 0.33333333 0.33333333]
#  [0.03846154 0.15384615 0.61538462 0.19230769]]
# Nº neurônios: 45
#
# 120/120 [==============================] - 0s 911us/step
# 280/280 [==============================] - 0s 0us/step
# 1.1006512959798178 50.83
# Normalized confusion matrix
# [[0.85294118 0.02941176 0.         0.11764706]
#  [0.06060606 0.45454545 0.21212121 0.27272727]
#  [0.11111111 0.22222222 0.40740741 0.25925926]
#  [0.03846154 0.26923077 0.46153846 0.23076923]]
# Nº neurônios: 50
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 36us/step
# 1.050362801551819 51.67
# Normalized confusion matrix
# [[0.94117647 0.         0.02941176 0.02941176]
#  [0.03030303 0.51515152 0.15151515 0.3030303 ]
#  [0.11111111 0.18518519 0.37037037 0.33333333]
#  [0.         0.5        0.38461538 0.11538462]]
# Nº neurônios: 60
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 37us/step
# 1.1109792629877726 47.5
# Normalized confusion matrix
# [[0.88235294 0.         0.         0.11764706]
#  [0.03030303 0.36363636 0.39393939 0.21212121]
#  [0.11111111 0.18518519 0.40740741 0.2962963 ]
#  [0.         0.30769231 0.53846154 0.15384615]]
# Nº neurônios: 70
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 31us/step
# 1.1026286522547404 50.0
# Normalized confusion matrix
# [[0.88235294 0.         0.         0.11764706]
#  [0.03030303 0.45454545 0.18181818 0.33333333]
#  [0.07407407 0.14814815 0.37037037 0.40740741]
#  [0.         0.19230769 0.61538462 0.19230769]]
# Nº neurônios: 80
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 32us/step
# 1.1080052693684896 51.67
# Normalized confusion matrix
# [[0.88235294 0.         0.05882353 0.05882353]
#  [0.03030303 0.57575758 0.18181818 0.21212121]
#  [0.03703704 0.25925926 0.33333333 0.37037037]
#  [0.         0.23076923 0.61538462 0.15384615]]
# Nº neurônios: 90
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 33us/step
# 1.114446258544922 51.67
# Normalized confusion matrix
# [[0.88235294 0.         0.         0.11764706]
#  [0.         0.51515152 0.3030303  0.18181818]
#  [0.07407407 0.14814815 0.40740741 0.37037037]
#  [0.         0.15384615 0.69230769 0.15384615]]
# Nº neurônios: 100
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 43us/step
# 1.1615386883417764 49.17
# Normalized confusion matrix
# [[0.82352941 0.02941176 0.         0.14705882]
#  [0.06060606 0.39393939 0.24242424 0.3030303 ]
#  [0.07407407 0.18518519 0.48148148 0.25925926]
#  [0.         0.26923077 0.53846154 0.19230769]]
# Nº neurônios: 200
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 0us/step
# 1.3198045333226522 53.33
# Normalized confusion matrix
# [[0.88235294 0.02941176 0.         0.08823529]
#  [0.03030303 0.39393939 0.24242424 0.33333333]
#  [0.03703704 0.22222222 0.48148148 0.25925926]
#  [0.         0.19230769 0.5        0.30769231]]
# Nº neurônios: 300
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 0us/step
# 1.370292067527771 47.5
# Normalized confusion matrix
# [[0.85294118 0.         0.02941176 0.11764706]
#  [0.09090909 0.39393939 0.27272727 0.24242424]
#  [0.03703704 0.2962963  0.37037037 0.2962963 ]
#  [0.         0.30769231 0.5        0.19230769]]
# Nº neurônios: 400
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 56us/step
# 1.4997785329818725 52.5
# Normalized confusion matrix
# [[0.91176471 0.         0.         0.08823529]
#  [0.09090909 0.45454545 0.21212121 0.24242424]
#  [0.03703704 0.2962963  0.44444444 0.22222222]
#  [0.         0.23076923 0.57692308 0.19230769]]
# Nº neurônios: 500
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 56us/step
# 1.5638307571411132 47.5
# Normalized confusion matrix
# [[0.85294118 0.         0.02941176 0.11764706]
#  [0.06060606 0.51515152 0.27272727 0.15151515]
#  [0.03703704 0.37037037 0.25925926 0.33333333]
#  [0.         0.34615385 0.5        0.15384615]]
# Nº neurônios: 600
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 56us/step
# 1.716933544476827 50.83
# Normalized confusion matrix
# [[0.91176471 0.         0.02941176 0.05882353]
#  [0.09090909 0.36363636 0.24242424 0.3030303 ]
#  [0.         0.22222222 0.44444444 0.33333333]
#  [0.         0.15384615 0.61538462 0.23076923]]
# Nº neurônios: 700
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 33us/step
# 1.689218560854594 49.17
# Normalized confusion matrix
# [[0.88235294 0.02941176 0.         0.08823529]
#  [0.06060606 0.45454545 0.21212121 0.27272727]
#  [0.03703704 0.37037037 0.33333333 0.25925926]
#  [0.         0.23076923 0.57692308 0.19230769]]
# Nº neurônios: 800
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 90us/step
# 1.813956650098165 46.67
# Normalized confusion matrix
# [[0.91176471 0.         0.         0.08823529]
#  [0.09090909 0.3030303  0.33333333 0.27272727]
#  [0.03703704 0.22222222 0.37037037 0.37037037]
#  [0.         0.15384615 0.65384615 0.19230769]]
# Nº neurônios: 900
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 88us/step
# 1.9055281639099122 47.5
# Normalized confusion matrix
# [[0.91176471 0.         0.         0.08823529]
#  [0.09090909 0.39393939 0.3030303  0.21212121]
#  [0.03703704 0.2962963  0.37037037 0.2962963 ]
#  [0.         0.19230769 0.69230769 0.11538462]]
# Nº neurônios: 1000
#
# 120/120 [==============================] - 0s 3ms/step
# 280/280 [==============================] - 0s 36us/step
# 2.037342977523804 46.67
# Normalized confusion matrix
# [[0.88235294 0.         0.         0.11764706]
#  [0.09090909 0.33333333 0.24242424 0.33333333]
#  [0.03703704 0.22222222 0.37037037 0.37037037]
#  [0.         0.15384615 0.65384615 0.19230769]]

# %%
file.close()

# %%
valores=np.loadtxt("results_fullorbit_data100-10_atek3_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom full orbit até k=3, 100-10, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom full orbit até k=3, 100-10, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()
