# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz_fullorbit_data1000-100_atek4.csv", delimiter=",")

data2=[]
for i in range(data.shape[0]):
    if data[i][100]!=4:
        data2.append(data[i])

data3=np.asarray(data2)
dataset=data3[:,0:100].copy()
label=data3[:,100:101].copy()
    

dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_fullorbit_data1000-100_atek3_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(100,), activation='relu'))
    model.add(Dense(4, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom full orbit até k=3, 1000-100, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom full orbit até k=3, 1000-100, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1','2','3']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 1200/1200 [==============================] - 0s 80us/step
# 2800/2800 [==============================] - 0s 30us/step
# 1.183367267449697 53.33
# Normalized confusion matrix
# [[0.99339934 0.         0.00330033 0.00330033]
#  [0.00320513 0.51923077 0.20512821 0.2724359 ]
#  [0.         0.38297872 0.27659574 0.34042553]
#  [0.00990099 0.37953795 0.28382838 0.32673267]]
# Nº neurônios: 10
#
# 1200/1200 [==============================] - 0s 73us/step
# 2800/2800 [==============================] - 0s 33us/step
# 1.180637494723002 51.25
# Normalized confusion matrix
# [[0.98019802 0.         0.00990099 0.00990099]
#  [0.00320513 0.25641026 0.40384615 0.33653846]
#  [0.0141844  0.20212766 0.45390071 0.32978723]
#  [0.01980198 0.20132013 0.41584158 0.3630363 ]]
# Nº neurônios: 15
#
# 1200/1200 [==============================] - 0s 76us/step
# 2800/2800 [==============================] - 0s 27us/step
# 1.6811880826950074 52.42
# Normalized confusion matrix
# [[0.98349835 0.         0.00990099 0.00660066]
#  [0.01282051 0.36217949 0.30128205 0.32371795]
#  [0.02836879 0.23404255 0.37234043 0.36524823]
#  [0.05610561 0.25742574 0.31353135 0.37293729]]
# Nº neurônios: 20
#
# 1200/1200 [==============================] - 0s 81us/step
# 2800/2800 [==============================] - 0s 28us/step
# 1.610279974937439 52.08
# Normalized confusion matrix
# [[0.97029703 0.00660066 0.01320132 0.00990099]
#  [0.01602564 0.42948718 0.33333333 0.22115385]
#  [0.0141844  0.33687943 0.40070922 0.24822695]
#  [0.02970297 0.3630363  0.330033   0.27722772]]
# Nº neurônios: 25
#
# 1200/1200 [==============================] - 0s 141us/step
# 2800/2800 [==============================] - 0s 29us/step
# 2.033117709159851 51.83
# Normalized confusion matrix
# [[0.95709571 0.         0.02310231 0.01980198]
#  [0.00961538 0.42628205 0.28525641 0.27884615]
#  [0.0106383  0.34751773 0.33687943 0.30496454]
#  [0.01980198 0.37953795 0.25742574 0.34323432]]
# Nº neurônios: 30
#
# 1200/1200 [==============================] - 0s 97us/step
# 2800/2800 [==============================] - 0s 30us/step
# 2.8870183054606118 50.58
# Normalized confusion matrix
# [[0.98019802 0.         0.00660066 0.01320132]
#  [0.01602564 0.28846154 0.37179487 0.32371795]
#  [0.0248227  0.25886525 0.38652482 0.32978723]
#  [0.00990099 0.22772277 0.3960396  0.36633663]]
# Nº neurônios: 35
#
# 1200/1200 [==============================] - 0s 104us/step
# 2800/2800 [==============================] - 0s 30us/step
# 3.6122450923919676 51.42
# Normalized confusion matrix
# [[0.95379538 0.01980198 0.00660066 0.01980198]
#  [0.01923077 0.42948718 0.20833333 0.34294872]
#  [0.0177305  0.34751773 0.29432624 0.34042553]
#  [0.01320132 0.34983498 0.27062706 0.36633663]]
# Nº neurônios: 40
#
# 1200/1200 [==============================] - 0s 131us/step
# 2800/2800 [==============================] - 0s 28us/step
# 4.210069144566853 50.25
# Normalized confusion matrix
# [[0.98349835 0.         0.00990099 0.00660066]
#  [0.01923077 0.36538462 0.29166667 0.32371795]
#  [0.0212766  0.28014184 0.34751773 0.35106383]
#  [0.02970297 0.32673267 0.33663366 0.30693069]]
# Nº neurônios: 45
#
# 1200/1200 [==============================] - 0s 135us/step
# 2800/2800 [==============================] - 0s 31us/step
# 4.142856740951538 51.0
# Normalized confusion matrix
# [[0.98019802 0.00330033 0.00990099 0.00660066]
#  [0.00320513 0.42307692 0.30769231 0.26602564]
#  [0.0070922  0.31914894 0.36879433 0.30496454]
#  [0.01980198 0.39273927 0.32673267 0.26072607]]
# Nº neurônios: 50
#
# 1200/1200 [==============================] - 0s 147us/step
# 2800/2800 [==============================] - 0s 29us/step
# 3.995719763437907 47.5
# Normalized confusion matrix
# [[0.98679868 0.         0.00330033 0.00990099]
#  [0.00961538 0.31410256 0.28205128 0.39423077]
#  [0.0212766  0.31560284 0.26950355 0.39361702]
#  [0.01650165 0.35313531 0.31023102 0.32013201]]
# Nº neurônios: 60
#
# 1200/1200 [==============================] - 0s 145us/step
# 2800/2800 [==============================] - 0s 34us/step
# 3.993234640757243 51.75
# Normalized confusion matrix
# [[0.98349835 0.00990099 0.00660066 0.        ]
#  [0.01282051 0.34935897 0.29807692 0.33974359]
#  [0.0177305  0.29432624 0.33333333 0.35460993]
#  [0.00660066 0.31023102 0.28712871 0.3960396 ]]
# Nº neurônios: 70
#
# 1200/1200 [==============================] - 0s 158us/step
# 2800/2800 [==============================] - 0s 32us/step
# 4.156292667388916 49.17
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.01282051 0.34615385 0.31410256 0.32692308]
#  [0.0070922  0.34397163 0.30851064 0.34042553]
#  [0.02970297 0.32343234 0.34323432 0.30363036]]
# Nº neurônios: 80
#
# 1200/1200 [==============================] - 0s 165us/step
# 2800/2800 [==============================] - 0s 30us/step
# 3.9948612531026204 50.75
# Normalized confusion matrix
# [[0.99009901 0.00330033 0.00330033 0.00330033]
#  [0.01282051 0.3974359  0.33012821 0.25961538]
#  [0.0106383  0.32978723 0.34397163 0.31560284]
#  [0.02310231 0.33663366 0.34983498 0.29042904]]
# Nº neurônios: 90
#
# 1200/1200 [==============================] - 0s 167us/step
# 2800/2800 [==============================] - 0s 32us/step
# 4.115881144205729 48.83
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.36538462 0.31410256 0.31730769]
#  [0.0248227  0.33333333 0.28368794 0.35815603]
#  [0.01980198 0.33663366 0.34983498 0.29372937]]
# Nº neurônios: 100
#
# 1200/1200 [==============================] - 0s 187us/step
# 2800/2800 [==============================] - 0s 27us/step
# 3.7481436347961425 51.25
# Normalized confusion matrix
# [[0.99339934 0.         0.         0.00660066]
#  [0.00320513 0.38782051 0.33012821 0.27884615]
#  [0.0035461  0.32624113 0.36879433 0.30141844]
#  [0.01650165 0.32013201 0.36963696 0.29372937]]
# Nº neurônios: 200
#
# 1200/1200 [==============================] - 0s 196us/step
# 2800/2800 [==============================] - 0s 32us/step
# 3.4850536314646403 52.08
# Normalized confusion matrix
# [[0.99339934 0.         0.00330033 0.00330033]
#  [0.00641026 0.40705128 0.25961538 0.32692308]
#  [0.0035461  0.30851064 0.34751773 0.34042553]
#  [0.01980198 0.330033   0.32343234 0.32673267]]
# Nº neurônios: 300
#
# 1200/1200 [==============================] - 0s 212us/step
# 2800/2800 [==============================] - 0s 38us/step
# 4.2614378674825035 51.42
# Normalized confusion matrix
# [[0.97689769 0.         0.01320132 0.00990099]
#  [0.         0.17307692 0.38141026 0.44551282]
#  [0.0106383  0.06737589 0.43617021 0.4858156 ]
#  [0.         0.09240924 0.43234323 0.47524752]]
# Nº neurônios: 400
#
# 1200/1200 [==============================] - 0s 214us/step
# 2800/2800 [==============================] - 0s 40us/step
# 3.252593231201172 52.25
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00961538 0.36538462 0.28205128 0.34294872]
#  [0.0106383  0.30851064 0.36524823 0.31560284]
#  [0.00990099 0.31023102 0.32673267 0.35313531]]
# Nº neurônios: 500
#
# 1200/1200 [==============================] - 0s 226us/step
# 2800/2800 [==============================] - 0s 43us/step
# 3.353950074513753 50.5
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.37179487 0.29487179 0.33012821]
#  [0.0106383  0.32269504 0.34042553 0.32624113]
#  [0.00660066 0.33333333 0.35973597 0.30033003]]
# Nº neurônios: 600
#
# 1200/1200 [==============================] - 0s 244us/step
# 2800/2800 [==============================] - 0s 40us/step
# 3.2440955225626626 53.08
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00961538 0.38782051 0.29487179 0.30769231]
#  [0.0106383  0.31205674 0.39361702 0.28368794]
#  [0.00660066 0.27722772 0.37953795 0.33663366]]
# Nº neurônios: 700
#
# 1200/1200 [==============================] - 0s 257us/step
# 2800/2800 [==============================] - 0s 39us/step
# 3.3864116541544598 51.67
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00961538 0.41025641 0.2724359  0.30769231]
#  [0.0212766  0.34397163 0.35106383 0.28368794]
#  [0.01980198 0.3630363  0.32013201 0.2970297 ]]
# Nº neurônios: 800
#
# 1200/1200 [==============================] - 0s 263us/step
# 2800/2800 [==============================] - 0s 39us/step
# 3.5075131924947103 53.75
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00641026 0.41987179 0.31730769 0.25641026]
#  [0.0070922  0.32624113 0.40780142 0.25886525]
#  [0.00990099 0.32343234 0.34983498 0.31683168]]
# Nº neurônios: 900
#
# 1200/1200 [==============================] - 0s 275us/step
# 2800/2800 [==============================] - 0s 39us/step
# 3.3101873524983723 51.92
# Normalized confusion matrix
# [[0.99669967 0.00330033 0.         0.        ]
#  [0.00961538 0.41666667 0.30769231 0.26602564]
#  [0.0212766  0.36879433 0.34397163 0.26595745]
#  [0.01980198 0.34653465 0.32343234 0.31023102]]
# Nº neurônios: 1000
#
# 1200/1200 [==============================] - 0s 282us/step
# 2800/2800 [==============================] - 0s 47us/step
# 3.279401470820109 52.67
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.00320513 0.39102564 0.29807692 0.30769231]
#  [0.0035461  0.33687943 0.35460993 0.30496454]
#  [0.00990099 0.30693069 0.330033   0.35313531]]

# %%
file.close()

# %%
valores=np.loadtxt("results_fullorbit_data1000-100_atek3_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom full orbit até k=3, 1000-100, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom full orbit até k=3, 1000-100, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()
