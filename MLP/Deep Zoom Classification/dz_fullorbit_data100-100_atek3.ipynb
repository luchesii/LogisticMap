# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz_fullorbit_data100-100_atek4.csv", delimiter=",")

data2=[]
for i in range(data.shape[0]):
    if data[i][100]!=4:
        data2.append(data[i])

data3=np.asarray(data2)
dataset=data3[:,0:100].copy()
label=data3[:,100:101].copy()
    

dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_fullorbit_data100-100_atek3_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(100,), activation='relu'))
    model.add(Dense(4, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom full orbit até k=3, 100-100, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom full orbit até k=3, 100-100, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1','2','3']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 120/120 [==============================] - 0s 318us/step
# 280/280 [==============================] - 0s 36us/step
# 1.8813536326090494 36.67
# Normalized confusion matrix
# [[0.58823529 0.         0.14705882 0.26470588]
#  [0.21212121 0.12121212 0.24242424 0.42424242]
#  [0.14814815 0.14814815 0.40740741 0.2962963 ]
#  [0.11538462 0.38461538 0.15384615 0.34615385]]
# Nº neurônios: 10
#
# 120/120 [==============================] - 0s 407us/step
# 280/280 [==============================] - 0s 39us/step
# 2.6666515032450357 43.33
# Normalized confusion matrix
# [[0.64705882 0.11764706 0.14705882 0.08823529]
#  [0.18181818 0.21212121 0.33333333 0.27272727]
#  [0.25925926 0.18518519 0.2962963  0.25925926]
#  [0.03846154 0.03846154 0.34615385 0.57692308]]
# Nº neurônios: 15
#
# 120/120 [==============================] - 0s 558us/step
# 280/280 [==============================] - 0s 32us/step
# 2.8319340070088703 42.5
# Normalized confusion matrix
# [[0.79411765 0.05882353 0.05882353 0.08823529]
#  [0.09090909 0.18181818 0.36363636 0.36363636]
#  [0.22222222 0.18518519 0.25925926 0.33333333]
#  [0.07692308 0.23076923 0.26923077 0.42307692]]
# Nº neurônios: 20
#
# 120/120 [==============================] - 0s 741us/step
# 280/280 [==============================] - 0s 46us/step
# 2.6517624378204347 46.67
# Normalized confusion matrix
# [[0.82352941 0.02941176 0.05882353 0.08823529]
#  [0.24242424 0.21212121 0.3030303  0.24242424]
#  [0.14814815 0.11111111 0.40740741 0.33333333]
#  [0.11538462 0.23076923 0.26923077 0.38461538]]
# Nº neurônios: 25
#
# 120/120 [==============================] - 0s 733us/step
# 280/280 [==============================] - 0s 39us/step
# 2.768280363082886 44.17
# Normalized confusion matrix
# [[0.73529412 0.05882353 0.11764706 0.08823529]
#  [0.18181818 0.27272727 0.21212121 0.33333333]
#  [0.18518519 0.14814815 0.2962963  0.37037037]
#  [0.11538462 0.23076923 0.23076923 0.42307692]]
# Nº neurônios: 30
#
# 120/120 [==============================] - 0s 766us/step
# 280/280 [==============================] - 0s 46us/step
# 3.023498026529948 43.33
# Normalized confusion matrix
# [[0.82352941 0.05882353 0.08823529 0.02941176]
#  [0.18181818 0.18181818 0.27272727 0.36363636]
#  [0.11111111 0.14814815 0.33333333 0.40740741]
#  [0.19230769 0.19230769 0.26923077 0.34615385]]
# Nº neurônios: 35
#
# 120/120 [==============================] - 0s 874us/step
# 280/280 [==============================] - 0s 39us/step
# 2.808601951599121 46.67
# Normalized confusion matrix
# [[0.97058824 0.02941176 0.         0.        ]
#  [0.21212121 0.24242424 0.24242424 0.3030303 ]
#  [0.11111111 0.22222222 0.2962963  0.37037037]
#  [0.15384615 0.19230769 0.38461538 0.26923077]]
# Nº neurônios: 40
#
# 120/120 [==============================] - 0s 974us/step
# 280/280 [==============================] - 0s 43us/step
# 2.7733844916025796 52.5
# Normalized confusion matrix
# [[0.91176471 0.02941176 0.02941176 0.02941176]
#  [0.12121212 0.27272727 0.27272727 0.33333333]
#  [0.18518519 0.11111111 0.44444444 0.25925926]
#  [0.07692308 0.15384615 0.34615385 0.42307692]]
# Nº neurônios: 45
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 54us/step
# 2.618472131093343 51.67
# Normalized confusion matrix
# [[0.94117647 0.         0.02941176 0.02941176]
#  [0.21212121 0.27272727 0.27272727 0.24242424]
#  [0.11111111 0.22222222 0.33333333 0.33333333]
#  [0.11538462 0.19230769 0.23076923 0.46153846]]
# Nº neurônios: 50
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 46us/step
# 2.7345964431762697 51.67
# Normalized confusion matrix
# [[0.94117647 0.         0.02941176 0.02941176]
#  [0.18181818 0.27272727 0.21212121 0.33333333]
#  [0.11111111 0.18518519 0.33333333 0.37037037]
#  [0.07692308 0.19230769 0.26923077 0.46153846]]
# Nº neurônios: 60
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 43us/step
# 2.8759678681691487 46.67
# Normalized confusion matrix
# [[0.88235294 0.         0.08823529 0.02941176]
#  [0.15151515 0.18181818 0.42424242 0.24242424]
#  [0.14814815 0.22222222 0.37037037 0.25925926]
#  [0.11538462 0.19230769 0.30769231 0.38461538]]
# Nº neurônios: 70
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 39us/step
# 2.5198416392008465 50.0
# Normalized confusion matrix
# [[0.88235294 0.         0.08823529 0.02941176]
#  [0.27272727 0.24242424 0.18181818 0.3030303 ]
#  [0.14814815 0.11111111 0.37037037 0.37037037]
#  [0.07692308 0.19230769 0.26923077 0.46153846]]
# Nº neurônios: 80
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 43us/step
# 2.6263858954111736 50.0
# Normalized confusion matrix
# [[0.85294118 0.         0.05882353 0.08823529]
#  [0.15151515 0.21212121 0.24242424 0.39393939]
#  [0.14814815 0.11111111 0.37037037 0.37037037]
#  [0.03846154 0.15384615 0.26923077 0.53846154]]
# Nº neurônios: 90
#
# 120/120 [==============================] - 0s 1ms/step
# 280/280 [==============================] - 0s 43us/step
# 2.492896787325541 49.17
# Normalized confusion matrix
# [[0.91176471 0.         0.05882353 0.02941176]
#  [0.12121212 0.24242424 0.36363636 0.27272727]
#  [0.07407407 0.14814815 0.33333333 0.44444444]
#  [0.03846154 0.23076923 0.30769231 0.42307692]]
# Nº neurônios: 100
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 39us/step
# 2.5639162699381512 52.5
# Normalized confusion matrix
# [[0.97058824 0.02941176 0.         0.        ]
#  [0.15151515 0.18181818 0.27272727 0.39393939]
#  [0.14814815 0.11111111 0.40740741 0.33333333]
#  [0.11538462 0.15384615 0.23076923 0.5       ]]
# Nº neurônios: 200
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 46us/step
# 2.9057909647623696 48.33
# Normalized confusion matrix
# [[0.91176471 0.         0.05882353 0.02941176]
#  [0.12121212 0.15151515 0.21212121 0.51515152]
#  [0.14814815 0.18518519 0.33333333 0.33333333]
#  [0.07692308 0.19230769 0.23076923 0.5       ]]
# Nº neurônios: 300
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 54us/step
# 2.7022499561309816 48.33
# Normalized confusion matrix
# [[0.91176471 0.02941176 0.02941176 0.02941176]
#  [0.09090909 0.24242424 0.3030303  0.36363636]
#  [0.18518519 0.14814815 0.2962963  0.37037037]
#  [0.07692308 0.19230769 0.30769231 0.42307692]]
# Nº neurônios: 400
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 86us/step
# 2.5272844950358073 53.33
# Normalized confusion matrix
# [[0.94117647 0.         0.02941176 0.02941176]
#  [0.09090909 0.24242424 0.27272727 0.39393939]
#  [0.18518519 0.14814815 0.40740741 0.25925926]
#  [0.11538462 0.19230769 0.19230769 0.5       ]]
# Nº neurônios: 500
#
# 120/120 [==============================] - 2s 15ms/step
# 280/280 [==============================] - 0s 139us/step
# 2.604001506169637 51.67
# Normalized confusion matrix
# [[0.91176471 0.         0.05882353 0.02941176]
#  [0.06060606 0.24242424 0.3030303  0.39393939]
#  [0.11111111 0.11111111 0.44444444 0.33333333]
#  [0.03846154 0.19230769 0.34615385 0.42307692]]
# Nº neurônios: 600
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 50us/step
# 2.7095473766326905 50.0
# Normalized confusion matrix
# [[0.94117647 0.         0.02941176 0.02941176]
#  [0.12121212 0.18181818 0.33333333 0.36363636]
#  [0.14814815 0.18518519 0.33333333 0.33333333]
#  [0.03846154 0.19230769 0.26923077 0.5       ]]
# Nº neurônios: 700
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 54us/step
# 2.6138950030008954 50.83
# Normalized confusion matrix
# [[0.94117647 0.         0.02941176 0.02941176]
#  [0.12121212 0.21212121 0.24242424 0.42424242]
#  [0.18518519 0.18518519 0.33333333 0.2962963 ]
#  [0.07692308 0.19230769 0.23076923 0.5       ]]
# Nº neurônios: 800
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 54us/step
# 2.8006428241729737 51.67
# Normalized confusion matrix
# [[0.94117647 0.         0.02941176 0.02941176]
#  [0.09090909 0.21212121 0.27272727 0.42424242]
#  [0.11111111 0.18518519 0.37037037 0.33333333]
#  [0.03846154 0.19230769 0.26923077 0.5       ]]
# Nº neurônios: 900
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 57us/step
# 2.7029259045918783 50.83
# Normalized confusion matrix
# [[0.91176471 0.         0.05882353 0.02941176]
#  [0.15151515 0.21212121 0.27272727 0.36363636]
#  [0.07407407 0.14814815 0.40740741 0.37037037]
#  [0.03846154 0.23076923 0.26923077 0.46153846]]
# Nº neurônios: 1000
#
# 120/120 [==============================] - 0s 2ms/step
# 280/280 [==============================] - 0s 54us/step
# 2.7665039539337157 50.83
# Normalized confusion matrix
# [[0.91176471 0.02941176 0.02941176 0.02941176]
#  [0.09090909 0.21212121 0.27272727 0.42424242]
#  [0.14814815 0.18518519 0.37037037 0.2962963 ]
#  [0.03846154 0.19230769 0.26923077 0.5       ]]

# %%
file.close()

# %%
valores=np.loadtxt("results_fullorbit_data100-100_atek3_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom full orbit até k=3, 100-100, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom full orbit até k=3, 100-100, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()
