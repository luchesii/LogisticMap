# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz-data1000_atek4.csv", delimiter=",")

dataset=data[:,0:2].copy()
label=data[:,2:3].copy()
    
dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_logis_data10000_atek4_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(2,), activation='relu'))
    model.add(Dense(5, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom até k=4, 1000, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom até k=4, 1000, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1','2','3','4']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 1500/1500 [==============================] - 0s 47us/step
# 3500/3500 [==============================] - 0s 29us/step
# 1.528774756749471 29.4
# Normalized confusion matrix
# [[0.90429043 0.09570957 0.         0.         0.        ]
#  [0.34013605 0.14965986 0.0952381  0.         0.41496599]
#  [0.37417219 0.19205298 0.06291391 0.         0.37086093]
#  [0.37785016 0.15635179 0.08469055 0.         0.38110749]
#  [0.3877551  0.19387755 0.06462585 0.         0.3537415 ]]
# Nº neurônios: 10
#
# 1500/1500 [==============================] - 0s 53us/step
# 3500/3500 [==============================] - 0s 29us/step
# 1.4459943933486938 31.13
# Normalized confusion matrix
# [[0.92409241 0.         0.         0.07590759 0.        ]
#  [0.35034014 0.16666667 0.19387755 0.04081633 0.24829932]
#  [0.31456954 0.25165563 0.18543046 0.05298013 0.19536424]
#  [0.33876221 0.24104235 0.14983713 0.06840391 0.2019544 ]
#  [0.3537415  0.20748299 0.17346939 0.05782313 0.20748299]]
# Nº neurônios: 15
#
# 1500/1500 [==============================] - 0s 60us/step
# 3500/3500 [==============================] - 0s 28us/step
# 1.364993221918742 35.27
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.18367347 0.12585034 0.18707483 0.19047619 0.31292517]
#  [0.23178808 0.18874172 0.20529801 0.11589404 0.25827815]
#  [0.23778502 0.14332248 0.20521173 0.1465798  0.26710098]
#  [0.2244898  0.14285714 0.19727891 0.15646259 0.27891156]]
# Nº neurônios: 20
#
# 1500/1500 [==============================] - 0s 66us/step
# 3500/3500 [==============================] - 0s 27us/step
# 1.3637689304351808 36.33
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.19047619 0.32312925 0.15646259 0.16326531 0.16666667]
#  [0.21523179 0.37748344 0.18874172 0.11589404 0.10264901]
#  [0.2247557  0.3029316  0.18241042 0.15635179 0.13355049]
#  [0.21428571 0.34353741 0.17006803 0.1292517  0.14285714]]
# Nº neurônios: 25
#
# 1500/1500 [==============================] - 0s 74us/step
# 3500/3500 [==============================] - 0s 28us/step
# 1.3646258204778035 36.07
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.17346939 0.04421769 0.21428571 0.35034014 0.21768707]
#  [0.21523179 0.05629139 0.2384106  0.28145695 0.20860927]
#  [0.22149837 0.04885993 0.21498371 0.31596091 0.19869707]
#  [0.21428571 0.04761905 0.2244898  0.32312925 0.19047619]]
# Nº neurônios: 30
#
# 1500/1500 [==============================] - 0s 82us/step
# 3500/3500 [==============================] - 0s 28us/step
# 1.3740856065750122 35.87
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.18027211 0.32653061 0.19047619 0.21088435 0.09183673]
#  [0.21854305 0.35761589 0.20529801 0.13245033 0.08609272]
#  [0.21824104 0.33876221 0.2019544  0.15635179 0.08469055]
#  [0.21768707 0.32653061 0.19727891 0.15986395 0.09863946]]
# Nº neurônios: 35
#
# 1500/1500 [==============================] - 0s 90us/step
# 3500/3500 [==============================] - 0s 29us/step
# 1.323259108543396 38.13
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.12244898 0.18707483 0.12585034 0.34013605 0.2244898 ]
#  [0.15231788 0.1986755  0.18874172 0.2615894  0.1986755 ]
#  [0.17263844 0.16286645 0.14006515 0.29967427 0.2247557 ]
#  [0.14965986 0.17346939 0.14285714 0.31292517 0.22108844]]
# Nº neurônios: 40
#
# 1500/1500 [==============================] - 0s 97us/step
# 3500/3500 [==============================] - 0s 29us/step
# 1.3352820224761963 36.47
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.13605442 0.2585034  0.16326531 0.36394558 0.07823129]
#  [0.17549669 0.29470199 0.16887417 0.29801325 0.06291391]
#  [0.19543974 0.22149837 0.18566775 0.30944625 0.08794788]
#  [0.17346939 0.26530612 0.15306122 0.33333333 0.07482993]]
# Nº neurônios: 45
#
# 1500/1500 [==============================] - 0s 104us/step
# 3500/3500 [==============================] - 0s 28us/step
# 1.356802545229594 35.8
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.19387755 0.41836735 0.10884354 0.27210884 0.00680272]
#  [0.2218543  0.43046358 0.12251656 0.21192053 0.01324503]
#  [0.23452769 0.39739414 0.11726384 0.23127036 0.01954397]
#  [0.22789116 0.44557823 0.08843537 0.22789116 0.01020408]]
# Nº neurônios: 50
#
# 1500/1500 [==============================] - 0s 111us/step
# 3500/3500 [==============================] - 0s 30us/step
# 1.325700608253479 35.93
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.13265306 0.10884354 0.32653061 0.35034014 0.08163265]
#  [0.17880795 0.11258278 0.31125828 0.31456954 0.08278146]
#  [0.17915309 0.1009772  0.31270358 0.30618893 0.1009772 ]
#  [0.15646259 0.12244898 0.31632653 0.35034014 0.05442177]]
# Nº neurônios: 60
#
# 1500/1500 [==============================] - 0s 121us/step
# 3500/3500 [==============================] - 0s 30us/step
# 1.3114525594711304 37.47
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.10544218 0.34693878 0.19727891 0.30612245 0.04421769]
#  [0.15562914 0.37748344 0.22516556 0.21192053 0.02980132]
#  [0.1465798  0.31921824 0.24104235 0.24429967 0.04885993]
#  [0.1462585  0.37414966 0.18027211 0.25170068 0.04761905]]
# Nº neurônios: 70
#
# 1500/1500 [==============================] - 0s 128us/step
# 3500/3500 [==============================] - 0s 30us/step
# 1.2957610336939493 36.27
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.12585034 0.08163265 0.17687075 0.19047619 0.42517007]
#  [0.1589404  0.10264901 0.2384106  0.16225166 0.33774834]
#  [0.16938111 0.1009772  0.22801303 0.15309446 0.3485342 ]
#  [0.15646259 0.10204082 0.19047619 0.21768707 0.33333333]]
# Nº neurônios: 80
#
# 1500/1500 [==============================] - 0s 134us/step
# 3500/3500 [==============================] - 0s 29us/step
# 1.3192409620285035 37.27
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.11904762 0.26530612 0.10884354 0.27891156 0.22789116]
#  [0.15562914 0.27152318 0.16225166 0.26821192 0.14238411]
#  [0.16938111 0.247557   0.1237785  0.25407166 0.20521173]
#  [0.15646259 0.25510204 0.12585034 0.28911565 0.17346939]]
# Nº neurônios: 90
#
# 1500/1500 [==============================] - 0s 142us/step
# 3500/3500 [==============================] - 0s 30us/step
# 1.315795321146647 36.47
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.12585034 0.11564626 0.13945578 0.32653061 0.29251701]
#  [0.16225166 0.13907285 0.17218543 0.29470199 0.23178808]
#  [0.18241042 0.14006515 0.16286645 0.28338762 0.23127036]
#  [0.16326531 0.16326531 0.1122449  0.31972789 0.2414966 ]]
# Nº neurônios: 100
#
# 1500/1500 [==============================] - 0s 151us/step
# 3500/3500 [==============================] - 0s 30us/step
# 1.2952173137664795 37.2
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.09183673 0.07142857 0.13605442 0.38095238 0.31972789]
#  [0.11258278 0.08278146 0.18211921 0.39735099 0.22516556]
#  [0.13355049 0.09446254 0.14983713 0.36482085 0.25732899]
#  [0.1292517  0.09183673 0.16326531 0.3877551  0.22789116]]
# Nº neurônios: 200
#
# 1500/1500 [==============================] - 0s 157us/step
# 3500/3500 [==============================] - 0s 31us/step
# 1.2905998020172118 37.87
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.08503401 0.05442177 0.15646259 0.36734694 0.33673469]
#  [0.10596026 0.06291391 0.20529801 0.38410596 0.24172185]
#  [0.12052117 0.06514658 0.18892508 0.36482085 0.26058632]
#  [0.11904762 0.07142857 0.18027211 0.37414966 0.25510204]]
# Nº neurônios: 300
#
# 1500/1500 [==============================] - 0s 169us/step
# 3500/3500 [==============================] - 0s 33us/step
# 1.2740261977513632 37.73
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.0952381  0.20408163 0.12244898 0.36054422 0.21768707]
#  [0.1192053  0.21192053 0.16556291 0.39403974 0.10927152]
#  [0.13355049 0.19869707 0.13355049 0.36807818 0.16612378]
#  [0.11904762 0.20748299 0.14285714 0.39455782 0.13605442]]
# Nº neurônios: 400
#
# 1500/1500 [==============================] - 0s 177us/step
# 3500/3500 [==============================] - 0s 33us/step
# 1.2783496974309285 36.87
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.09863946 0.1122449  0.12244898 0.26190476 0.4047619 ]
#  [0.1192053  0.13576159 0.16887417 0.28145695 0.29470199]
#  [0.13680782 0.14332248 0.13680782 0.24104235 0.34201954]
#  [0.12585034 0.1292517  0.14965986 0.28231293 0.31292517]]
# Nº neurônios: 500
#
# 1500/1500 [==============================] - 0s 189us/step
# 3500/3500 [==============================] - 0s 33us/step
# 1.2676118065516153 38.4
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.10204082 0.06802721 0.23129252 0.29931973 0.29931973]
#  [0.10927152 0.06622517 0.29139073 0.32450331 0.20860927]
#  [0.11400651 0.0781759  0.25732899 0.32247557 0.22801303]
#  [0.1292517  0.07482993 0.25510204 0.31632653 0.2244898 ]]
# Nº neurônios: 600
#
# 1500/1500 [==============================] - 0s 192us/step
# 3500/3500 [==============================] - 0s 34us/step
# 1.2731937805811564 38.73
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.09863946 0.03401361 0.26190476 0.29251701 0.31292517]
#  [0.11589404 0.02317881 0.34768212 0.2615894  0.25165563]
#  [0.14006515 0.03583062 0.27687296 0.27035831 0.27687296]
#  [0.12244898 0.03401361 0.27210884 0.29931973 0.27210884]]
# Nº neurônios: 700
#
# 1500/1500 [==============================] - 0s 199us/step
# 3500/3500 [==============================] - 0s 35us/step
# 1.2762955048878988 36.53
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.08843537 0.17687075 0.10204082 0.11904762 0.51360544]
#  [0.10596026 0.25827815 0.14900662 0.10596026 0.3807947 ]
#  [0.11726384 0.22149837 0.14006515 0.10423453 0.41693811]
#  [0.11564626 0.26190476 0.11564626 0.1122449  0.39455782]]
# Nº neurônios: 800
#
# 1500/1500 [==============================] - 0s 225us/step
# 3500/3500 [==============================] - 0s 37us/step
# 1.2713785486221314 37.87
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.09863946 0.21088435 0.15986395 0.28231293 0.24829932]
#  [0.1192053  0.25827815 0.23509934 0.2218543  0.16556291]
#  [0.14006515 0.25081433 0.16938111 0.27687296 0.16286645]
#  [0.12244898 0.26190476 0.17687075 0.27891156 0.15986395]]
# Nº neurônios: 900
#
# 1500/1500 [==============================] - 0s 240us/step
# 3500/3500 [==============================] - 0s 36us/step
# 1.2848722257614136 38.27
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.06802721 0.34013605 0.22108844 0.2244898  0.1462585 ]
#  [0.08278146 0.39403974 0.28145695 0.17218543 0.06953642]
#  [0.09771987 0.37785016 0.21498371 0.20521173 0.10423453]
#  [0.10544218 0.38095238 0.22108844 0.21428571 0.07823129]]
# Nº neurônios: 1000
#
# 1500/1500 [==============================] - 0s 247us/step
# 3500/3500 [==============================] - 0s 38us/step
# 1.2847402976353963 38.13
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.08843537 0.04081633 0.11564626 0.07823129 0.67687075]
#  [0.10596026 0.04304636 0.22847682 0.07615894 0.54635762]
#  [0.1237785  0.05537459 0.15635179 0.04560261 0.61889251]
#  [0.11564626 0.05442177 0.15306122 0.08503401 0.59183673]]

# %%
file.close()

# %%
import numpy as np
import matplotlib.pyplot as plt 

valores=np.loadtxt("results_logis_data10000_atek4_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom até k=4, 1000, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom até k=4, 1000, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()
