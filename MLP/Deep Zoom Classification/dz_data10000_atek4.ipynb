# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz-data10000_atek4.csv", delimiter=",")

dataset=data[:,0:2].copy()
label=data[:,2:3].copy()
    
dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_logis_data10000_atek4_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(2,), activation='relu'))
    model.add(Dense(5, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom até k=4, 10000, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom até k=4, 10000, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1','2','3','4']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 15000/15000 [==============================] - 0s 30us/step
# 35000/35000 [==============================] - 1s 25us/step
# 1.5103384796142578 30.33
# Normalized confusion matrix
# [[0.88278146 0.         0.02748344 0.         0.0897351 ]
#  [0.37528755 0.         0.0598094  0.         0.56490306]
#  [0.41594106 0.         0.07568654 0.         0.5083724 ]
#  [0.38262911 0.         0.06673374 0.         0.55063716]
#  [0.37655776 0.         0.06500505 0.         0.55843718]]
# Nº neurônios: 10
#
# 15000/15000 [==============================] - 0s 29us/step
# 35000/35000 [==============================] - 1s 27us/step
# 1.3020654161453247 37.45
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.13604995 0.42129477 0.14229379 0.27735787 0.02300361]
#  [0.17314133 0.4038848  0.16577361 0.2367716  0.02042867]
#  [0.14319249 0.41918176 0.15191147 0.25754527 0.02816901]
#  [0.13371506 0.42371169 0.15089256 0.27382957 0.01785113]]
# Nº neurônios: 15
#
# 15000/15000 [==============================] - 0s 30us/step
# 35000/35000 [==============================] - 1s 27us/step
# 1.313135430463155 36.99
# Normalized confusion matrix
# [[0.96390728 0.         0.         0.03609272 0.        ]
#  [0.11633257 0.         0.1738416  0.33782452 0.37200131]
#  [0.14835901 0.         0.183858   0.30843938 0.3593436 ]
#  [0.13413816 0.         0.17102616 0.3323273  0.36250838]
#  [0.11417986 0.         0.18019535 0.33614011 0.36948467]]
# Nº neurônios: 20
#
# 15000/15000 [==============================] - 0s 30us/step
# 35000/35000 [==============================] - 1s 26us/step
# 1.2978924336751303 37.39
# Normalized confusion matrix
# [[0.97086093 0.         0.02913907 0.         0.        ]
#  [0.1238909  0.         0.15280973 0.1452514  0.57804798]
#  [0.15338245 0.         0.17113195 0.12993972 0.54554588]
#  [0.14050973 0.         0.1462106  0.1462106  0.56706908]
#  [0.12428427 0.         0.15089256 0.14247221 0.58235096]]
# Nº neurônios: 25
#
# 15000/15000 [==============================] - 0s 32us/step
# 35000/35000 [==============================] - 1s 28us/step
# 1.2371811528523764 38.87
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.07328294 0.02234637 0.27472889 0.24318107 0.38646073]
#  [0.09912927 0.02545211 0.30843938 0.23978567 0.32719357]
#  [0.08651911 0.02515091 0.27833669 0.24614353 0.36384977]
#  [0.07477265 0.02526103 0.28460761 0.24924217 0.36611654]]
# Nº neurônios: 30
#
# 15000/15000 [==============================] - 1s 34us/step
# 35000/35000 [==============================] - 1s 28us/step
# 1.2066788557052612 39.67
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.05389418 0.20900427 0.1965166  0.30561945 0.23496549]
#  [0.06898861 0.20562626 0.25083724 0.28600134 0.18854655]
#  [0.06237425 0.20355466 0.20187793 0.31153588 0.22065728]
#  [0.0538902  0.22768609 0.20410913 0.30683732 0.20747727]]
# Nº neurônios: 35
#
# 15000/15000 [==============================] - 1s 34us/step
# 35000/35000 [==============================] - 1s 28us/step
# 1.2398312999725343 39.18
# Normalized confusion matrix
# [[0.99470199 0.         0.00529801 0.         0.        ]
#  [0.06769635 0.21557673 0.21886296 0.18731515 0.3105488 ]
#  [0.09310114 0.22136638 0.26724715 0.15371735 0.26456798]
#  [0.0731053  0.21898055 0.23138833 0.18041583 0.29610999]
#  [0.07140451 0.23206467 0.21657124 0.18322668 0.29673291]]
# Nº neurônios: 40
#
# 15000/15000 [==============================] - 1s 35us/step
# 35000/35000 [==============================] - 1s 28us/step
# 1.187896730295817 40.41
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.05225107 0.02366086 0.25139665 0.29674663 0.37594479]
#  [0.06296048 0.02746149 0.33389149 0.27461487 0.30107167]
#  [0.05533199 0.02917505 0.26760563 0.31052985 0.33735748]
#  [0.05085888 0.03637588 0.25934658 0.30111149 0.35230717]]
# Nº neurônios: 45
#
# 15000/15000 [==============================] - 1s 37us/step
# 35000/35000 [==============================] - 1s 28us/step
# 1.192372702217102 40.72
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.05159382 0.05750904 0.38087414 0.170884   0.33913901]
#  [0.06262559 0.04889484 0.47186872 0.14166109 0.27494977]
#  [0.05499665 0.05902079 0.41482227 0.16934943 0.30181087]
#  [0.04883799 0.04715392 0.3896935  0.17783766 0.33647693]]
# Nº neurônios: 50
#
# 15000/15000 [==============================] - 1s 36us/step
# 35000/35000 [==============================] - 1s 29us/step
# 1.2107150318781534 40.49
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.06539599 0.38777522 0.2050608  0.33946763 0.00230036]
#  [0.08171467 0.32886805 0.28365707 0.30241125 0.00334896]
#  [0.07344064 0.36351442 0.22199866 0.33936955 0.00167673]
#  [0.07005726 0.37622095 0.21185584 0.33715056 0.00471539]]
# Nº neurônios: 60
#
# 15000/15000 [==============================] - 1s 39us/step
# 35000/35000 [==============================] - 1s 29us/step
# 1.2018583515803019 41.08
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.05257969 0.40979297 0.31186329 0.22576405 0.        ]
#  [0.06396517 0.34929672 0.41728064 0.16945747 0.        ]
#  [0.05902079 0.37458082 0.34875922 0.21763917 0.        ]
#  [0.05085888 0.39845066 0.32670933 0.22398114 0.        ]]
# Nº neurônios: 70
#
# 15000/15000 [==============================] - 1s 39us/step
# 35000/35000 [==============================] - 1s 28us/step
# 1.2040291563034058 40.25
# Normalized confusion matrix
# [[0.98774834 0.         0.01225166 0.         0.        ]
#  [0.04600723 0.43378245 0.1396648  0.30660532 0.07394019]
#  [0.05793704 0.40522438 0.20663094 0.26657736 0.06363027]
#  [0.05399061 0.41817572 0.14654594 0.30784708 0.07344064]
#  [0.04580667 0.43920512 0.13876726 0.3088582  0.06736275]]
# Nº neurônios: 80
#
# 15000/15000 [==============================] - 1s 39us/step
# 35000/35000 [==============================] - 1s 29us/step
# 1.2042674317042033 40.29
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.05685179 0.03877752 0.30693395 0.49227736 0.10515938]
#  [0.06965841 0.035499   0.39149364 0.42196919 0.08137977]
#  [0.06438632 0.02984574 0.31891348 0.49362844 0.09322602]
#  [0.05826878 0.03940721 0.31997305 0.49309532 0.08925564]]
# Nº neurônios: 90
#
# 15000/15000 [==============================] - 1s 40us/step
# 35000/35000 [==============================] - 1s 29us/step
# 1.188434325281779 40.39
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.0469931  0.30759119 0.33815314 0.17679921 0.13046336]
#  [0.06061621 0.28298727 0.41962492 0.14567984 0.09109176]
#  [0.05231388 0.29309188 0.36284373 0.17236754 0.11938296]
#  [0.04917481 0.32569889 0.33411923 0.17817447 0.1128326 ]]
# Nº neurônios: 100
#
# 15000/15000 [==============================] - 1s 42us/step
# 35000/35000 [==============================] - 1s 29us/step
# 1.1882477673212688 40.79
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.04403549 0.05027933 0.15741045 0.16825501 0.58001972]
#  [0.05592766 0.06496986 0.24279973 0.1486939  0.48760884]
#  [0.04963112 0.06002683 0.1713615  0.17974514 0.53923541]
#  [0.04479623 0.06433142 0.16739643 0.15628158 0.56719434]]
# Nº neurônios: 200
#
# 15000/15000 [==============================] - 1s 43us/step
# 35000/35000 [==============================] - 1s 30us/step
# 1.1888049257278441 40.79
# Normalized confusion matrix
# [[9.94701987e-01 0.00000000e+00 5.29801325e-03 0.00000000e+00
#   0.00000000e+00]
#  [4.46927374e-02 2.62898455e-03 3.47354584e-01 2.46795925e-01
#   3.58527769e-01]
#  [5.42531815e-02 3.34896182e-04 4.49430676e-01 2.18017415e-01
#   2.77963831e-01]
#  [4.96311201e-02 2.01207243e-03 3.75922200e-01 2.51173709e-01
#   3.21260899e-01]
#  [4.37857865e-02 4.04176490e-03 3.62748400e-01 2.47221287e-01
#   3.42202762e-01]]
# Nº neurônios: 300
#
# 15000/15000 [==============================] - 1s 46us/step
# 35000/35000 [==============================] - 1s 31us/step
# 1.1906771683375041 40.93
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.04929346 0.33322379 0.1994742  0.39829116 0.01971738]
#  [0.06028131 0.28700603 0.29370395 0.34661755 0.01239116]
#  [0.05365526 0.29979879 0.23239437 0.39570758 0.018444  ]
#  [0.04782755 0.32906703 0.22903334 0.37790502 0.01616706]]
# Nº neurônios: 400
#
# 15000/15000 [==============================] - 1s 46us/step
# 35000/35000 [==============================] - 1s 31us/step
# 1.1857362827301026 41.48
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.04896484 0.36542885 0.27867236 0.3020046  0.00492935]
#  [0.05827194 0.29705291 0.39283322 0.24782317 0.00401875]
#  [0.05432596 0.32427901 0.31321261 0.30348759 0.00469484]
#  [0.04883799 0.37049512 0.29639609 0.28022903 0.00404176]]
# Nº neurônios: 500
#
# 15000/15000 [==============================] - 1s 47us/step
# 35000/35000 [==============================] - 1s 32us/step
# 1.1947261359532675 40.21
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.04633585 0.31942162 0.18994413 0.28458758 0.15971081]
#  [0.05894173 0.31212324 0.26758205 0.2454789  0.11587408]
#  [0.05432596 0.32293763 0.20355466 0.27867203 0.14050973]
#  [0.04715392 0.34186595 0.19232065 0.28056585 0.13809363]]
# Nº neurônios: 600
#
# 15000/15000 [==============================] - 1s 50us/step
# 35000/35000 [==============================] - 1s 34us/step
# 1.1890659632364908 39.91
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.04206375 0.31646402 0.1537956  0.19717384 0.29050279]
#  [0.05157401 0.30040188 0.20462157 0.16141996 0.28198259]
#  [0.0472837  0.30415828 0.15224681 0.19818913 0.29812207]
#  [0.04311216 0.33681374 0.15661839 0.1936679  0.26978781]]
# Nº neurônios: 700
#
# 15000/15000 [==============================] - 1s 50us/step
# 35000/35000 [==============================] - 1s 32us/step
# 1.2626499895731609 40.13
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.0640815  0.10713112 0.16398291 0.14886625 0.51593822]
#  [0.08707301 0.09209645 0.22505023 0.12893503 0.46684528]
#  [0.07545272 0.10764588 0.17236754 0.15828303 0.48625084]
#  [0.07308858 0.10104412 0.1690805  0.14179859 0.51498821]]
# Nº neurônios: 800
#
# 15000/15000 [==============================] - 1s 50us/step
# 35000/35000 [==============================] - 1s 33us/step
# 1.2091390906651815 40.05
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.05882353 0.11633257 0.2093329  0.37298718 0.24252383]
#  [0.07367716 0.11286001 0.29336906 0.33121232 0.18888145]
#  [0.0620389  0.10764588 0.23272971 0.38095238 0.21663313]
#  [0.05793196 0.13742001 0.21690805 0.37824183 0.20949815]]
# Nº neurônios: 900
#
# 15000/15000 [==============================] - 1s 52us/step
# 35000/35000 [==============================] - 1s 33us/step
# 1.198244744237264 40.28
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.05323694 0.12093329 0.17022675 0.47025961 0.18534341]
#  [0.06597455 0.11553918 0.24849297 0.42163429 0.14835901]
#  [0.05902079 0.10831657 0.18343394 0.48122066 0.16800805]
#  [0.05321657 0.13910408 0.17110138 0.47591782 0.16066015]]
# Nº neurônios: 1000
#
# 15000/15000 [==============================] - 1s 52us/step
# 35000/35000 [==============================] - 1s 33us/step
# 1.2013201090494792 41.05
# Normalized confusion matrix
# [[1.         0.         0.         0.         0.        ]
#  [0.03910615 0.2122905  0.13276372 0.19717384 0.41866579]
#  [0.04889484 0.22103148 0.20462157 0.18017415 0.34527796]
#  [0.04225352 0.21395037 0.14218645 0.22199866 0.379611  ]
#  [0.03940721 0.2280229  0.13438868 0.18794207 0.41023914]]

# %%
file.close()

# %%
import numpy as np
import matplotlib.pyplot as plt 

valores=np.loadtxt("results_logis_data10000_atek4_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom até k=4, 10000, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom até k=4, 10000, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()
