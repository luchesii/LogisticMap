# %%
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

np.random.seed(10)

data=np.loadtxt("dz-data10000_atek4.csv", delimiter=",")

data2=[]
for i in range(data.shape[0]):
    if data[i][2]==0 or data[i][2]==1:
        data2.append(data[i])

data3=np.asarray(data2)
dataset=data3[:,0:2].copy()
label=data3[:,2:3].copy()
    
dtrain,dtest,ltrain,ltest=train_test_split(dataset,label,train_size=0.7,random_state=10)
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#função tirada do sklearn

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
file= open("results_logis_data10000_atek1_1.csv","w+")

n1=5


while n1<=1000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(2,), activation='relu'))
    model.add(Dense(2, activation='softmax'))

    #model.summary()

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=['accuracy'])


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=300, batch_size=10,verbose=0)

    loss,accur = model.evaluate(dtest, ltest)

    losstrain,acctrain = model.evaluate(dtrain, ltrain)
    
    acctrain=round(acctrain*100,2)
    accur=round(accur*100,2)

    print(loss, accur)
    file.write('{}'.format(n1))
    file.write(',')
    file.write('{}'.format(acctrain))
    file.write(',')
    file.write('{}'.format(accur))
    file.write('\n')
    
    plt.plot(history.history['acc'])
    plt.title('Deep zoom até k=1, 10.000, 1 camada oculta, neur=%i' %n1)
    plt.ylabel('Acurácia')
    plt.xlabel('epoca')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.title('Deep zoom até k=1, 10.000, 1 camada oculta neur=%i' %n1)
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    MCon = confusion_matrix(ltest,model.predict_classes(dtest,batch_size=10,verbose=0))
    
    Mcon_lab=['0','1']
    
    plot_confusion_matrix(MCon,Mcon_lab,'Matriz de confusão')
    
    plt.show()
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 6000/6000 [==============================] - 0s 32us/step
# 14000/14000 [==============================] - 0s 26us/step
# 0.4995264774958293 76.6
# Normalized confusion matrix
# [[0.85345683 0.14654317]
#  [0.3228082  0.6771918 ]]
# Nº neurônios: 10
#
# 6000/6000 [==============================] - 0s 32us/step
# 14000/14000 [==============================] - 0s 27us/step
# 0.4159806175231934 76.97
# Normalized confusion matrix
# [[0.87859742 0.12140258]
#  [0.34094726 0.65905274]]
# Nº neurônios: 15
#
# 6000/6000 [==============================] - 0s 39us/step
# 14000/14000 [==============================] - 0s 27us/step
# 0.21753163369496664 93.42
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.13268391 0.86731609]]
# Nº neurônios: 20
#
# 6000/6000 [==============================] - 0s 40us/step
# 14000/14000 [==============================] - 0s 27us/step
# 0.18994164238373437 94.62
# Normalized confusion matrix
# [[0.99801522 0.00198478]
#  [0.10648304 0.89351696]]
# Nº neurônios: 25
#
# 6000/6000 [==============================] - 0s 45us/step
# 14000/14000 [==============================] - 0s 27us/step
# 0.18933226883411408 94.78
# Normalized confusion matrix
# [[1.        0.       ]
#  [0.1051394 0.8948606]]
# Nº neurônios: 30
#
# 6000/6000 [==============================] - 0s 39us/step
# 14000/14000 [==============================] - 0s 28us/step
# 0.18782876666386922 94.73
# Normalized confusion matrix
# [[9.99338406e-01 6.61594443e-04]
#  [1.05475311e-01 8.94524689e-01]]
# Nº neurônios: 35
#
# 6000/6000 [==============================] - 0s 43us/step
# 14000/14000 [==============================] - 0s 28us/step
# 0.12038395071029663 97.5
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.05038629 0.94961371]]
# Nº neurônios: 40
#
# 6000/6000 [==============================] - 0s 48us/step
# 14000/14000 [==============================] - 0s 27us/step
# 0.11059403897325198 97.05
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.05945583 0.94054417]]
# Nº neurônios: 45
#
# 6000/6000 [==============================] - 0s 49us/step
# 14000/14000 [==============================] - 0s 28us/step
# 0.1988745905359586 93.67
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.12764528 0.87235472]]
# Nº neurônios: 50
#
# 6000/6000 [==============================] - 0s 49us/step
# 14000/14000 [==============================] - 0s 28us/step
# 0.09558947655558586 97.8
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.04433994 0.95566006]]
# Nº neurônios: 60
#
# 6000/6000 [==============================] - 0s 54us/step
# 14000/14000 [==============================] - 0s 29us/step
# 0.09209292822082837 97.07
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.05911992 0.94088008]]
# Nº neurônios: 70
#
# 6000/6000 [==============================] - 0s 56us/step
# 14000/14000 [==============================] - 0s 29us/step
# 0.08032614042858283 97.72
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.04601948 0.95398052]]
# Nº neurônios: 80
#
# 6000/6000 [==============================] - 0s 58us/step
# 14000/14000 [==============================] - 0s 29us/step
# 0.09739167420069376 97.4
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.05240175 0.94759825]]
# Nº neurônios: 90
#
# 6000/6000 [==============================] - 0s 60us/step
# 14000/14000 [==============================] - 0s 28us/step
# 0.08025072531402111 97.62
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.04803493 0.95196507]]
# Nº neurônios: 100
#
# 6000/6000 [==============================] - 0s 62us/step
# 14000/14000 [==============================] - 0s 30us/step
# 0.09302499887347221 97.17
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.05710447 0.94289553]]
# Nº neurônios: 200
#
# 6000/6000 [==============================] - 0s 63us/step
# 14000/14000 [==============================] - 0s 30us/step
# 0.09946810881296794 98.0
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.04030904 0.95969096]]
# Nº neurônios: 300
#
# 6000/6000 [==============================] - 0s 64us/step
# 14000/14000 [==============================] - 0s 30us/step
# 0.0809935614913702 97.62
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.04803493 0.95196507]]
# Nº neurônios: 400
#
# 6000/6000 [==============================] - 0s 68us/step
# 14000/14000 [==============================] - 0s 31us/step
# 0.0903771181156238 97.3
# Normalized confusion matrix
# [[1.        0.       ]
#  [0.0544172 0.9455828]]
# Nº neurônios: 500
#
# 6000/6000 [==============================] - 0s 68us/step
# 14000/14000 [==============================] - 0s 32us/step
# 0.08910256119569143 97.65
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.04736312 0.95263688]]
# Nº neurônios: 600
#
# 6000/6000 [==============================] - 0s 72us/step
# 14000/14000 [==============================] - 0s 32us/step
# 0.11720930198083321 96.67
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.06718173 0.93281827]]
# Nº neurônios: 700
#
# 6000/6000 [==============================] - 0s 73us/step
# 14000/14000 [==============================] - 0s 33us/step
# 0.09728238139798244 97.03
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.05979174 0.94020826]]
# Nº neurônios: 800
#
# 6000/6000 [==============================] - 0s 80us/step
# 14000/14000 [==============================] - 0s 33us/step
# 0.09238788645466169 98.18
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.03661404 0.96338596]]
# Nº neurônios: 900
#
# 6000/6000 [==============================] - 1s 87us/step
# 14000/14000 [==============================] - 1s 37us/step
# 0.10729790238539377 97.25
# Normalized confusion matrix
# [[0.98445253 0.01554747]
#  [0.03963722 0.96036278]]
# Nº neurônios: 1000
#
# 6000/6000 [==============================] - 0s 79us/step
# 14000/14000 [==============================] - 0s 32us/step
# 0.09261266875267028 97.83
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.04366812 0.95633188]]

# %%
file.close()

# %%
import numpy as np
import matplotlib.pyplot as plt 

valores=np.loadtxt("results_logis_data10000_atek1_1.csv", delimiter=",")

plt.plot(valores[:,0],valores[:,1])
plt.title('Deep zoom até k=1, 10.000, 1 camada oculta')
plt.ylabel('Acurácia treinamento')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(valores[:,0],valores[:,2])
plt.title('Deep zoom até k=1, 10.000, 1 camada oculta')
plt.ylabel('Acurácia teste')
plt.xlabel('Número de neurônios')
plt.show()

# %% [markdown]
# #
