# %%
import numpy as np

r=3.8
q=1
xn=1

k=2
L=13

file=np.loadtxt("logis_data1000_d10_v2.csv", delimiter=",")


lin=file.shape[0]
col=file.shape[1]


file2=open("dz-k2-l13-logis_data1000_d10_v2.csv", "w+")
file3=open("dz-k2-l13-logis_lab_data1000_d10_v2.csv", "w+")

# %%
for i in range (lin):
    for j in range (col):
        a=file[i][j]
        b=round(a*pow(10,1)-np.floor(a*pow(10,1)),L)
        print(a,b)
        
        file2.write('{}'.format(b))
        if j<col-1:
            file2.write(",")
            
        
    file2.write("\n")
    
    c=file[i][col-1]
    
    for ii in range(xn):
        print (ii)
        c=c*r*(1-c)
    c=round(c*pow(10,1)-np.floor(c*pow(10,1)),L)
    s=str(c*pow(10,q))[0:q]
    print(c,s)
    
    file3.write(s)
    file3.write('\n')
# Out:
# 0.932791759942591 0.3279175994259
# 0.23822691159802 0.3822691159802
# 0
# 0.8960443071626 8
# 0.249967796387614 0.4996779638761
# 0.71243880919559 0.1243880919559
# 0
# 0.7850505892073 7
# 0.9351786138563 0.351786138563
# 0.230354381360016 0.3035438136002
# 0
# 0.7370671332339 7
# 0.451459095511606 0.5145909551161
# 0.941046366247505 0.4104636624751
# 0
# 0.1081679071551 1
# 0.852883339949895 0.528833399499
# 0.476798723866066 0.7679872386607
# 0
# 0.4795446298588 4
# 0.869865284301365 0.6986528430137
# 0.430158751580948 0.3015875158095
# 0
# 0.3146436007322 3
# 0.929530388423323 0.2953038842332
# 0.248913852599455 0.4891385259946
# 0
# 0.104318370175 1
# 0.769930512026681 0.6993051202668
# 0.673122570972653 0.7312257097265
# 0
# 0.3610858659531 3
# 0.762148444851349 0.6214844485135
# 0.688857132875673 0.8885713287567
# 0
# 0.1446533677553 1
# 0.573584248283426 0.7358424828343
# 0.92942436193734 0.2942436193734
# 0
# 0.4925992602389 4
# 0.934856889410878 0.3485688941088
# ...

# %%
file2.close()
file3.close()
