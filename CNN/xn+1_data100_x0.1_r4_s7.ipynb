# %%
import numpy as np
from sklearn.cross_validation import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 

np.random.seed(10)

# %%
size=7

dataset=np.loadtxt("cnn_xn+1_data100_x0.1_r4_s7.csv", delimiter=",")

data=dataset[:,0:size**2].copy()
label=dataset[:,size**2:size**2+1].copy()

dtrain,dtest,ltrain,ltest=train_test_split(data,label,train_size=0.7,random_state=1)

# %%
n1=5

res_mse=[]
res_mae=[]
neur=[]

while n1<=2000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(size**2,), activation='relu'))
    model.add(Dense(1, activation='linear'))

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='mean_squared_error')


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

    mse = model.evaluate(dtest, ltest)
    

    msetrain = model.evaluate(dtrain, ltrain)
    

    plt.plot(history.history['loss'])
    plt.title('')
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    faprox = model.predict(dtest)
    mae=sum(abs(faprox-ltest))/ltest.shape[0]
    print(mse,msetrain,mae)
    
    neur.append(n1)
    res_mse.append(mse)
    res_mae.append(mae)
    
    plt.plot(faprox, 'ro')
    plt.plot(ltest, 'bo')
    plt.show()
    
    plt.plot(faprox, 'ro')
    plt.show()
    
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 30/30 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 71us/step
# 0.22480936348438263 0.11219082197972706 [0.41020083]
# Nº neurônios: 10
#
# 30/30 [==============================] - 0s 1ms/step
# 70/70 [==============================] - 0s 57us/step
# 0.1250963658094406 0.07519927855048861 [0.30209576]
# Nº neurônios: 15
#
# 30/30 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 71us/step
# 0.19753681123256683 0.10942224732467107 [0.37033768]
# Nº neurônios: 20
#
# 30/30 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 71us/step
# 0.12722720205783844 0.03806515418525253 [0.28640241]
# Nº neurônios: 25
#
# 30/30 [==============================] - 0s 2ms/step
# 70/70 [==============================] - 0s 71us/step
# 0.1776440292596817 0.042037148986543926 [0.3450063]
# Nº neurônios: 30
#
# 30/30 [==============================] - 0s 3ms/step
# 70/70 [==============================] - 0s 71us/step
# 0.19361288845539093 0.04546940273472241 [0.36736365]
# Nº neurônios: 35
#
# 30/30 [==============================] - 0s 3ms/step
# 70/70 [==============================] - 0s 71us/step
# 0.19079658389091492 0.03599911481142044 [0.35293085]
# Nº neurônios: 40
#
# 30/30 [==============================] - 0s 3ms/step
# 70/70 [==============================] - 0s 86us/step
# 0.1636493057012558 0.023953015889440266 [0.34210634]
# Nº neurônios: 45
#
# 30/30 [==============================] - 0s 4ms/step
# 70/70 [==============================] - 0s 57us/step
# 0.14951877295970917 0.004563270755378264 [0.3212373]
# Nº neurônios: 50
#
# 30/30 [==============================] - 0s 4ms/step
# 70/70 [==============================] - 0s 57us/step
# 0.12454847991466522 0.016335129897509303 [0.28212942]
# Nº neurônios: 60
#
# 30/30 [==============================] - 0s 4ms/step
# 70/70 [==============================] - 0s 143us/step
# 0.14428314566612244 0.022162823804787228 [0.31463896]
# Nº neurônios: 70
#
# 30/30 [==============================] - 0s 5ms/step
# 70/70 [==============================] - 0s 71us/step
# 0.13239942491054535 0.00924128908663988 [0.28266781]
# Nº neurônios: 80
#
# 30/30 [==============================] - 0s 5ms/step
# 70/70 [==============================] - 0s 144us/step
# 0.1649894416332245 0.0310267728886434 [0.34963715]
# Nº neurônios: 90
#
# 30/30 [==============================] - 0s 6ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.16890649497509003 0.01403097441153867 [0.33776249]
# Nº neurônios: 100
#
# 30/30 [==============================] - 0s 6ms/step
# 70/70 [==============================] - 0s 79us/step
# 0.1459132730960846 0.0011646534149934139 [0.32146319]
# Nº neurônios: 200
#
# 30/30 [==============================] - 0s 6ms/step
# 70/70 [==============================] - 0s 158us/step
# 0.19509264826774597 0.0005067879284199859 [0.36688919]
# Nº neurônios: 300
#
# 30/30 [==============================] - 0s 7ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.1844816952943802 0.00269857006413596 [0.36033894]
# Nº neurônios: 400
#
# 30/30 [==============================] - 0s 7ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.1643894761800766 3.45859945290223e-06 [0.34291344]
# Nº neurônios: 500
#
# 30/30 [==============================] - 0s 7ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.17571398615837097 1.1430500405497567e-06 [0.3337595]
# Nº neurônios: 600
#
# 30/30 [==============================] - 0s 7ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.14784903824329376 1.2568816828206763e-06 [0.31731774]
# Nº neurônios: 700
#
# 30/30 [==============================] - 0s 8ms/step
# 70/70 [==============================] - 0s 223us/step
# 0.13883443176746368 3.550869944644676e-06 [0.30999872]
# Nº neurônios: 800
#
# 30/30 [==============================] - 0s 8ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.14332009851932526 5.442813858280715e-07 [0.31729154]
# Nº neurônios: 900
#
# 30/30 [==============================] - 0s 9ms/step
# 70/70 [==============================] - 0s 223us/step
# 0.15099817514419556 4.018923090955338e-07 [0.32547743]
# Nº neurônios: 1000
#
# 30/30 [==============================] - 0s 9ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.16031242907047272 4.329392641011509e-06 [0.32789364]
# Nº neurônios: 1100
#
# 30/30 [==============================] - 0s 9ms/step
# 70/70 [==============================] - 0s 223us/step
# 0.15723657608032227 2.4907653458480386e-07 [0.33399945]
# Nº neurônios: 1200
#
# 30/30 [==============================] - 0s 10ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.1409922093153 3.288366010727779e-07 [0.30895308]
# Nº neurônios: 1300
#
# 30/30 [==============================] - 0s 9ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.14582706987857819 6.406406328096636e-07 [0.31979839]
# Nº neurônios: 1400
#
# 30/30 [==============================] - 0s 10ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.14910957217216492 5.318441269862109e-07 [0.31840859]
# Nº neurônios: 1500
#
# 30/30 [==============================] - 0s 11ms/step
# 70/70 [==============================] - 0s 223us/step
# 0.14366716146469116 2.3871843495726354e-06 [0.31897939]
# Nº neurônios: 1600
#
# 30/30 [==============================] - 0s 11ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.152695432305336 1.8796369788885516e-07 [0.32752136]
# Nº neurônios: 1700
#
# 30/30 [==============================] - 0s 14ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.13924120366573334 1.975690845158949e-06 [0.31648762]
# Nº neurônios: 1800
#
# 30/30 [==============================] - 0s 12ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.14581486582756042 5.12290173609082e-07 [0.30987799]
# Nº neurônios: 1900
#
# 30/30 [==============================] - 0s 13ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.15175238251686096 1.8006609804745365e-05 [0.32625577]
# Nº neurônios: 2000
#
# 30/30 [==============================] - 0s 13ms/step
# 70/70 [==============================] - 0s 0us/step
# 0.14352773129940033 2.5494081634341064e-07 [0.31088279]

# %%
res_mse=np.asarray(res_mse)
res_mae=np.asarray(res_mae)
neur=np.asarray(neur)

print(res_mae,res_mse)

plt.plot(neur,res_mse)
plt.title('mse')
plt.ylabel('mse')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(neur,res_mae)
plt.title('mse')
plt.ylabel('mse')
plt.xlabel('Número de neurônios')
plt.show()
# Out:
# [[0.41020083]
#  [0.30209576]
#  [0.37033768]
#  [0.28640241]
#  [0.3450063 ]
#  [0.36736365]
#  [0.35293085]
#  [0.34210634]
#  [0.3212373 ]
#  [0.28212942]
#  [0.31463896]
#  [0.28266781]
#  [0.34963715]
#  [0.33776249]
#  [0.32146319]
#  [0.36688919]
#  [0.36033894]
#  [0.34291344]
#  [0.3337595 ]
#  [0.31731774]
#  [0.30999872]
#  [0.31729154]
#  [0.32547743]
#  [0.32789364]
#  [0.33399945]
#  [0.30895308]
#  [0.31979839]
#  [0.31840859]
#  [0.31897939]
#  [0.32752136]
#  [0.31648762]
#  [0.30987799]
#  [0.32625577]
#  [0.31088279]] [0.22480936 0.12509637 0.19753681 0.1272272  0.17764403 0.19361289
#  0.19079658 0.16364931 0.14951877 0.12454848 0.14428315 0.13239942
#  0.16498944 0.16890649 0.14591327 0.19509265 0.1844817  0.16438948
#  0.17571399 0.14784904 0.13883443 0.1433201  0.15099818 0.16031243
#  0.15723658 0.14099221 0.14582707 0.14910957 0.14366716 0.15269543
#  0.1392412  0.14581487 0.15175238 0.14352773]
