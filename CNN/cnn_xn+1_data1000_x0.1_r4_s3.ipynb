# %%
import numpy as np
from sklearn.cross_validation import train_test_split
import keras
import matplotlib.pyplot as plt 

np.random.seed(10)

# %%
size=3

dataset=np.loadtxt("cnn_xn+1_data1000_x0.1_r4_s3.csv", delimiter=",")

data=dataset[:,0:size**2].copy()
label=dataset[:,size**2:size**2+1].copy()

dtrain,dtest,ltrain,ltest=train_test_split(data,label,train_size=0.7,random_state=1)
#print(dtrain)
dtrain=dtrain.reshape((dtrain.shape[0],size,size,1))
dtest=dtest.reshape((dtest.shape[0],size,size,1))
#print('oi',dtrain)

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
#model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
#model.add(Conv2D(64, (5, 5), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5, activation='relu'))
model.add(keras.layers.Dense(1, activation='relu'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c1')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c1')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 2ms/step
# 700/700 [==============================] - 0s 86us/step
# 0.04852508520086606 0.0431960227234023
# mae [0.18307349]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5, activation='relu'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=100,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c2')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c2')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 2ms/step
# 700/700 [==============================] - 0s 73us/step
# 0.12930498997370402 0.12020111812012536
# mae [0.32226534]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=100,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c3')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c3')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 2ms/step
# 700/700 [==============================] - 0s 66us/step
# 0.08997280597686767 0.07837661168404988
# mae [0.25855454]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(15, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')

history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c4')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)
  
plt.title('xn+1, 1000, s=3, c4')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 2ms/step
# 700/700 [==============================] - 0s 66us/step
# 0.1264334918061892 0.12060970979077476
# mae [0.31950875]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(90, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')

history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c5')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)
  
plt.title('xn+1, 1000, s=3, c5')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 2ms/step
# 700/700 [==============================] - 0s 69us/step
# 0.00561085299278299 0.005453567616641521
# mae [0.06140324]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(90, activation='relu'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c6')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c6')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 3ms/step
# 700/700 [==============================] - 0s 91us/step
# 0.0021437685936689377 0.0016707030537405185
# mae [0.03307349]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Conv2D(2, (2, 2), activation='relu'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(70, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c7')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c7')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 2ms/step
# 700/700 [==============================] - 0s 63us/step
# 0.12100143740574519 0.1089886012673378
# mae [0.30858867]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Conv2D(1, (2, 2), activation='relu'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(70, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c8')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c8')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 3ms/step
# 700/700 [==============================] - 0s 71us/step
# 0.12431382298469544 0.12263248022113528
# mae [0.31794133]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(70, activation='relu'))
model.add(keras.layers.Dense(15, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c9')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c9')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 1s 3ms/step
# 700/700 [==============================] - 0s 77us/step
# 0.0008142822049558163 0.0007267051259987056
# mae [0.02199427]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(2000, activation='relu'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+1, 1000, s=3, c10')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+1, 1000, s=3, c10')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 2s 6ms/step
# 700/700 [==============================] - 0s 126us/step
# 0.00022147368174046277 0.00012358011170623026
# mae [0.0120407]
