# %%
import numpy as np
from sklearn.cross_validation import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 

np.random.seed(10)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
size=3

dataset=np.loadtxt("cnn_xn+10_data100_x0.1_r4_s3.csv", delimiter=",")

data=dataset[:,0:size**2].copy()
label=dataset[:,size**2:size**2+1].copy()

dtrain,dtest,ltrain,ltest=train_test_split(data,label,train_size=0.7,random_state=1)

# %%
n1=5

res_mse=[]
res_mae=[]
neur=[]

while n1<=2000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(size**2,), activation='relu'))
    model.add(Dense(1, activation='linear'))

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='mean_squared_error')


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

    mse = model.evaluate(dtest, ltest)
    

    msetrain = model.evaluate(dtrain, ltrain)
    

    plt.plot(history.history['loss'])
    plt.title('')
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    faprox = model.predict(dtest)
    mae=sum(abs(faprox-ltest))/ltest.shape[0]
    print(mse,msetrain,mae)
    
    neur.append(n1)
    res_mse.append(mse)
    res_mae.append(mae)
    
    plt.plot(faprox, 'ro')
    plt.plot(ltest, 'bo')
    plt.show()
    
    plt.plot(faprox, 'ro')
    plt.show()
    
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 60/60 [==============================] - 0s 500us/step
# 140/140 [==============================] - 0s 50us/step
# 0.16107231775919598 0.12559296722923005 [0.36155427]
# Nº neurônios: 10
#
# 60/60 [==============================] - 0s 596us/step
# 140/140 [==============================] - 0s 57us/step
# 0.16949983735879262 0.14524872473308018 [0.3605793]
# Nº neurônios: 15
#
# 60/60 [==============================] - 0s 803us/step
# 140/140 [==============================] - 0s 50us/step
# 0.17055105070273083 0.13142701195819037 [0.36211654]
# Nº neurônios: 20
#
# 60/60 [==============================] - 0s 985us/step
# 140/140 [==============================] - 0s 50us/step
# 0.16884315609931946 0.10628459112984794 [0.35696115]
# Nº neurônios: 25
#
# 60/60 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 50us/step
# 0.18107216159502665 0.09486849840198244 [0.376154]
# Nº neurônios: 30
#
# 60/60 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 43us/step
# 0.16694924334685007 0.1023984466280256 [0.36370109]
# Nº neurônios: 35
#
# 60/60 [==============================] - 0s 1ms/step
# 140/140 [==============================] - 0s 36us/step
# 0.1930630067984263 0.09351477984871183 [0.38903917]
# Nº neurônios: 40
#
# 60/60 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 50us/step
# 0.1583550602197647 0.10383705922535487 [0.35076782]
# Nº neurônios: 45
#
# 60/60 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 64us/step
# 0.17465170721213022 0.09422093118940081 [0.36801997]
# Nº neurônios: 50
#
# 60/60 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.17324160933494567 0.08778567974056517 [0.36374356]
# Nº neurônios: 60
#
# 60/60 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 50us/step
# 0.18103123406569163 0.08127827580486024 [0.37942757]
# Nº neurônios: 70
#
# 60/60 [==============================] - 0s 2ms/step
# 140/140 [==============================] - 0s 50us/step
# 0.1756549616654714 0.0884980965937887 [0.3713909]
# Nº neurônios: 80
#
# 60/60 [==============================] - 0s 3ms/step
# 140/140 [==============================] - 0s 64us/step
# 0.17323136428991953 0.08907550764935357 [0.37144025]
# Nº neurônios: 90
#
# 60/60 [==============================] - 0s 3ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.18251317342122395 0.07957123858588082 [0.37026249]
# Nº neurônios: 100
#
# 60/60 [==============================] - 0s 3ms/step
# 140/140 [==============================] - 0s 43us/step
# 0.17903461654980976 0.08336916842630931 [0.37543066]
# Nº neurônios: 200
#
# 60/60 [==============================] - 0s 3ms/step
# 140/140 [==============================] - 0s 50us/step
# 0.19260295530160268 0.06932096843208585 [0.37998633]
# Nº neurônios: 300
#
# 60/60 [==============================] - 0s 3ms/step
# 140/140 [==============================] - 0s 64us/step
# 0.19021437267462413 0.06811881129230772 [0.37579621]
# Nº neurônios: 400
#
# 60/60 [==============================] - 0s 4ms/step
# 140/140 [==============================] - 0s 71us/step
# 0.18554528454939526 0.059965991122382024 [0.36737575]
# Nº neurônios: 500
#
# 60/60 [==============================] - 0s 4ms/step
# 140/140 [==============================] - 0s 50us/step
# 0.21149396200974782 0.06360494260277066 [0.39660373]
# Nº neurônios: 600
#
# 60/60 [==============================] - 0s 4ms/step
# 140/140 [==============================] - 0s 64us/step
# 0.1916527936855952 0.06082573447908674 [0.37903486]
# Nº neurônios: 700
#
# 60/60 [==============================] - 0s 4ms/step
# 140/140 [==============================] - 0s 43us/step
# 0.21395638982454937 0.059275247156620026 [0.39678552]
# Nº neurônios: 800
#
# 60/60 [==============================] - 0s 4ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.19986403981844583 0.05464301471199308 [0.38582674]
# Nº neurônios: 900
#
# 60/60 [==============================] - 0s 6ms/step
# 140/140 [==============================] - 0s 71us/step
# 0.20438842674096425 0.05133384551320757 [0.38468589]
# Nº neurônios: 1000
#
# 60/60 [==============================] - 0s 5ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.19530293742815655 0.05623809886830194 [0.37714165]
# Nº neurônios: 1100
#
# 60/60 [==============================] - 0s 5ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.2205248435338338 0.049610698861735206 [0.40085426]
# Nº neurônios: 1200
#
# 60/60 [==============================] - 0s 5ms/step
# 140/140 [==============================] - 0s 64us/step
# 0.22114747166633605 0.0468083381652832 [0.39781498]
# Nº neurônios: 1300
#
# 60/60 [==============================] - 0s 6ms/step
# 140/140 [==============================] - 0s 71us/step
# 0.20876433153947194 0.04898859603064401 [0.38833108]
# Nº neurônios: 1400
#
# 60/60 [==============================] - 0s 6ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.21542697648207346 0.04704364793641227 [0.39502316]
# Nº neurônios: 1500
#
# 60/60 [==============================] - 0s 6ms/step
# 140/140 [==============================] - 0s 86us/step
# 0.22597060004870098 0.04564784541726112 [0.40316167]
# Nº neurônios: 1600
#
# 60/60 [==============================] - 0s 6ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.22771919667720794 0.04803900388734681 [0.40675179]
# Nº neurônios: 1700
#
# 60/60 [==============================] - 0s 6ms/step
# 140/140 [==============================] - 0s 64us/step
# 0.2054941624403 0.047326967652354925 [0.38775253]
# Nº neurônios: 1800
#
# 60/60 [==============================] - 0s 6ms/step
# 140/140 [==============================] - 0s 57us/step
# 0.231960791349411 0.04562390595674515 [0.40895675]
# Nº neurônios: 1900
#
# 60/60 [==============================] - 0s 7ms/step
# 140/140 [==============================] - 0s 60us/step
# 0.23460016548633575 0.04474507485117231 [0.41208146]
# Nº neurônios: 2000
#
# 60/60 [==============================] - 0s 7ms/step
# 140/140 [==============================] - 0s 71us/step
# 0.21063383320967358 0.04573682567902974 [0.38888612]

# %%
res_mse=np.asarray(res_mse)
res_mae=np.asarray(res_mae)
neur=np.asarray(neur)

print(res_mae,res_mse)

plt.plot(neur,res_mse)
plt.title('mse')
plt.ylabel('mse')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(neur,res_mae)
plt.title('mse')
plt.ylabel('mse')
plt.xlabel('Número de neurônios')
plt.show()
# Out:
# [[0.36155427]
#  [0.3605793 ]
#  [0.36211654]
#  [0.35696115]
#  [0.376154  ]
#  [0.36370109]
#  [0.38903917]
#  [0.35076782]
#  [0.36801997]
#  [0.36374356]
#  [0.37942757]
#  [0.3713909 ]
#  [0.37144025]
#  [0.37026249]
#  [0.37543066]
#  [0.37998633]
#  [0.37579621]
#  [0.36737575]
#  [0.39660373]
#  [0.37903486]
#  [0.39678552]
#  [0.38582674]
#  [0.38468589]
#  [0.37714165]
#  [0.40085426]
#  [0.39781498]
#  [0.38833108]
#  [0.39502316]
#  [0.40316167]
#  [0.40675179]
#  [0.38775253]
#  [0.40895675]
#  [0.41208146]
#  [0.38888612]] [0.16107232 0.16949984 0.17055105 0.16884316 0.18107216 0.16694924
#  0.19306301 0.15835506 0.17465171 0.17324161 0.18103123 0.17565496
#  0.17323136 0.18251317 0.17903462 0.19260296 0.19021437 0.18554528
#  0.21149396 0.19165279 0.21395639 0.19986404 0.20438843 0.19530294
#  0.22052484 0.22114747 0.20876433 0.21542698 0.2259706  0.2277192
#  0.20549416 0.23196079 0.23460017 0.21063383]
