# %%
import numpy as np
from sklearn.cross_validation import train_test_split
import keras
import matplotlib.pyplot as plt 

np.random.seed(10)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
size=3

dataset=np.loadtxt("cnn_xn+5_data1000_x0.1_r4_s3.csv", delimiter=",")

data=dataset[:,0:size**2].copy()
label=dataset[:,size**2:size**2+1].copy()

dtrain,dtest,ltrain,ltest=train_test_split(data,label,train_size=0.7,random_state=1)
#print(dtrain)
dtrain=dtrain.reshape((dtrain.shape[0],size,size,1))
dtest=dtest.reshape((dtest.shape[0],size,size,1))
#print('oi',dtrain)

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
#model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
#model.add(Conv2D(64, (5, 5), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5, activation='relu'))
model.add(keras.layers.Dense(1, activation='relu'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c1')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c1')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 253us/step
# 700/700 [==============================] - 0s 54us/step
# 0.12820272912581762 0.12011989312512535
# mae [0.32269891]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5, activation='relu'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=100,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c2')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c2')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 446us/step
# 700/700 [==============================] - 0s 60us/step
# 0.12872632672389347 0.12142359333378928
# mae [0.32118495]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(5, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=100,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c3')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c3')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 703us/step
# 700/700 [==============================] - 0s 69us/step
# 0.127187663714091 0.12199111546788897
# mae [0.32141639]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(15, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')

history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c4')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)
  
plt.title('xn+5, 1000, s=3, c4')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 610us/step
# 700/700 [==============================] - 0s 54us/step
# 0.12821462432543437 0.12094700923987797
# mae [0.32251571]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(90, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')

history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c5')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)
  
plt.title('xn+5, 1000, s=3, c5')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 889us/step
# 700/700 [==============================] - 0s 63us/step
# 0.1300703485806783 0.12220184121813094
# mae [0.32396345]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(90, activation='relu'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c6')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c6')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 1ms/step
# 700/700 [==============================] - 0s 61us/step
# 0.13492724021275837 0.10709800043276378
# mae [0.32694742]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Conv2D(2, (2, 2), activation='relu'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(70, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c7')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c7')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 936us/step
# 700/700 [==============================] - 0s 66us/step
# 0.12635452916224799 0.12155284030096872
# mae [0.32053742]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Conv2D(1, (2, 2), activation='relu'))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(70, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c8')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c8')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 1ms/step
# 700/700 [==============================] - 0s 66us/step
# 0.12584922085205713 0.12303126769406456
# mae [0.3206236]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(70, activation='relu'))
model.add(keras.layers.Dense(15, activation='linear'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c9')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c9')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 1ms/step
# 700/700 [==============================] - 0s 54us/step
# 0.1368409260114034 0.10871050302471433
# mae [0.32800627]

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(2, kernel_size=(2, 2),
                 activation='relu',
                 input_shape=(3,3,1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(2000, activation='relu'))
model.add(keras.layers.Dense(1, activation='linear'))

model.compile(optimizer=keras.optimizers.Adam(),
              loss='mean_squared_error')


history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

mse = model.evaluate(dtest, ltest)
    

msetrain = model.evaluate(dtrain, ltrain)
    
print(mse,msetrain)
plt.plot(history.history['loss'])
plt.title('xn+5, 1000, s=3, c10')
plt.ylabel('loss')
plt.xlabel('epoca')
plt.show()
    
faprox = model.predict(dtest)

print('mae',sum(abs(faprox-ltest))/ltest.shape[0])
plt.title('xn+5, 1000, s=3, c10')
plt.plot(faprox, 'ro')
plt.plot(ltest, 'bo')
plt.show()
    
plt.plot(faprox, 'ro')
plt.show()
# Out:
# 300/300 [==============================] - 0s 1ms/step
# 700/700 [==============================] - 0s 78us/step
# 0.14206283619006474 0.10005547842809132
# mae [0.3257475]
