# %%
import numpy as np
from sklearn.cross_validation import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
import matplotlib.pyplot as plt 

np.random.seed(10)

# %%
size=7

dataset=np.loadtxt("cnn_xn+1_data1000_x0.1_r4_s7.csv", delimiter=",")

data=dataset[:,0:size**2].copy()
label=dataset[:,size**2:size**2+1].copy()

dtrain,dtest,ltrain,ltest=train_test_split(data,label,train_size=0.7,random_state=1)

# %%
n1=5

res_mse=[]
res_mae=[]
neur=[]

while n1<=2000:
    
    model = Sequential()
    model.add(Dense(n1, input_shape=(size**2,), activation='relu'))
    model.add(Dense(1, activation='linear'))

    adam=keras.optimizers.Adam()

    model.compile(optimizer=adam, loss='mean_squared_error')


    print("Nº neurônios:", n1,"\n")


    history = model.fit(dtrain, ltrain, epochs=75,verbose=0)

    mse = model.evaluate(dtest, ltest)
    

    msetrain = model.evaluate(dtrain, ltrain)
    

    plt.plot(history.history['loss'])
    plt.title('')
    plt.ylabel('loss')
    plt.xlabel('epoca')
    plt.show()
    
    faprox = model.predict(dtest)
    mae=sum(abs(faprox-ltest))/ltest.shape[0]
    print(mse,msetrain,mae)
    
    neur.append(n1)
    res_mse.append(mse)
    res_mae.append(mae)
    
    plt.plot(faprox, 'ro')
    plt.plot(ltest, 'bo')
    plt.show()
    
    plt.plot(faprox, 'ro')
    plt.show()
    
    
    if n1<50:
        n1+=5
    elif n1<100:
        n1+=10
    else:
        n1+=100
# Out:
# Nº neurônios: 5
#
# 300/300 [==============================] - 1s 3ms/step
# 700/700 [==============================] - 0s 109us/step
# 0.1264964238802592 0.1080351014648165 [0.31252841]
# Nº neurônios: 10
#
# 300/300 [==============================] - 1s 3ms/step
# 700/700 [==============================] - 0s 57us/step
# 0.13907794962326686 0.09708053192922048 [0.31938489]
# Nº neurônios: 15
#
# 300/300 [==============================] - 1s 3ms/step
# 700/700 [==============================] - 0s 70us/step
# 0.1306799371043841 0.06937415489128658 [0.30442556]
# Nº neurônios: 20
#
# 300/300 [==============================] - 1s 4ms/step
# 700/700 [==============================] - 0s 70us/step
# 0.13871369103590647 0.054137022410120285 [0.31083441]
# Nº neurônios: 25
#
# 300/300 [==============================] - 1s 3ms/step
# 700/700 [==============================] - 0s 69us/step
# 0.15320818295081456 0.056269806325435635 [0.326384]
# Nº neurônios: 30
#
# 300/300 [==============================] - 1s 4ms/step
# 700/700 [==============================] - 0s 71us/step
# 0.16080787350734074 0.05687386874641691 [0.33945305]
# Nº neurônios: 35
#
# 300/300 [==============================] - 1s 4ms/step
# 700/700 [==============================] - 0s 61us/step
# 0.1388970257838567 0.030501665771007536 [0.3068811]
# Nº neurônios: 40
#
# 300/300 [==============================] - 3s 10ms/step
# 700/700 [==============================] - 0s 72us/step
# 0.11899971395730972 0.012365855979067938 [0.28562733]
# Nº neurônios: 45
#
# 300/300 [==============================] - 1s 4ms/step
# 700/700 [==============================] - 0s 71us/step
# 0.1138648498058319 0.016718733715159553 [0.27707865]
# Nº neurônios: 50
#
# 300/300 [==============================] - 1s 4ms/step
# 700/700 [==============================] - 0s 64us/step
# 0.17015761603911717 0.01403218822819846 [0.33701709]
# Nº neurônios: 60
#
# 300/300 [==============================] - 1s 4ms/step
# 700/700 [==============================] - 0s 77us/step
# 0.10383119801680248 0.00892558999891792 [0.25775383]
# Nº neurônios: 70
#
# 300/300 [==============================] - 1s 5ms/step
# 700/700 [==============================] - 0s 87us/step
# 0.13579311708609262 0.0065982132564697945 [0.30380098]
# Nº neurônios: 80
#
# 300/300 [==============================] - 1s 5ms/step
# 700/700 [==============================] - 0s 79us/step
# 0.10667976150910059 0.004295306322830064 [0.27172361]
# Nº neurônios: 90
#
# 300/300 [==============================] - 1s 4ms/step
# 700/700 [==============================] - 0s 69us/step
# 0.13115174382925032 0.002159763416275382 [0.2943269]
# Nº neurônios: 100
#
# 300/300 [==============================] - 3s 9ms/step
# 700/700 [==============================] - 0s 67us/step
# 0.13597915331522623 0.0022408144335661615 [0.30859179]
# Nº neurônios: 200
#
# 300/300 [==============================] - 2s 8ms/step
# 700/700 [==============================] - 0s 107us/step
# 0.10638906796773274 9.010287010044391e-05 [0.26696456]
# Nº neurônios: 300
#
# 300/300 [==============================] - 1s 5ms/step
# 700/700 [==============================] - 0s 77us/step
# 0.10607570131619772 1.173814657834425e-05 [0.26968337]
# Nº neurônios: 400
#
# 300/300 [==============================] - 3s 10ms/step
# 700/700 [==============================] - 0s 111us/step
# 0.10883937984704971 5.31542597335439e-07 [0.2754043]
# Nº neurônios: 500
#
# 300/300 [==============================] - 2s 5ms/step
# 700/700 [==============================] - 0s 101us/step
# 0.10297633359829585 6.02025005978898e-06 [0.26638969]
# Nº neurônios: 600
#
# 300/300 [==============================] - 2s 5ms/step
# 700/700 [==============================] - 0s 100us/step
# 0.10150103827317555 4.55455498532891e-06 [0.26318796]
# Nº neurônios: 700
#
# 300/300 [==============================] - 2s 6ms/step
# 700/700 [==============================] - 0s 107us/step
# 0.09890011032422384 0.0023264866282365153 [0.26116142]
# Nº neurônios: 800
#
# 300/300 [==============================] - 3s 8ms/step
# 700/700 [==============================] - 0s 126us/step
# 0.090940559754769 0.0004250214292135622 [0.2509419]
# Nº neurônios: 900
#
# 300/300 [==============================] - 2s 7ms/step
# 700/700 [==============================] - 0s 114us/step
# 0.09611279795567194 0.005275719140523247 [0.25895321]
# Nº neurônios: 1000
#
# 300/300 [==============================] - 3s 11ms/step
# 700/700 [==============================] - 0s 121us/step
# 0.09771919657786687 0.002214299500254648 [0.26122364]
# Nº neurônios: 1100
#
# 300/300 [==============================] - 2s 7ms/step
# 700/700 [==============================] - 0s 123us/step
# 0.09677322298288345 0.003941172152491552 [0.25580338]
# Nº neurônios: 1200
#
# 300/300 [==============================] - 3s 9ms/step
# 700/700 [==============================] - 0s 116us/step
# 0.09607727964719137 0.0013083101017400622 [0.26125569]
# Nº neurônios: 1300
#
# 300/300 [==============================] - 2s 6ms/step
# 700/700 [==============================] - 0s 117us/step
# 0.08766483848293623 0.004228228572756052 [0.24245133]
# Nº neurônios: 1400
#
# 300/300 [==============================] - 4s 13ms/step
# 700/700 [==============================] - 0s 121us/step
# 0.08922754019498826 0.002984325324318239 [0.25265056]
# Nº neurônios: 1500
#
# 300/300 [==============================] - 3s 11ms/step
# 700/700 [==============================] - 0s 121us/step
# 0.0827211864789327 0.0016735723149031401 [0.23891012]
# Nº neurônios: 1600
#
# 300/300 [==============================] - 3s 10ms/step
# 700/700 [==============================] - 0s 114us/step
# 0.08724496990442276 0.0019782234156238182 [0.24534609]
# Nº neurônios: 1700
#
# 300/300 [==============================] - 2s 6ms/step
# 700/700 [==============================] - 0s 111us/step
# 0.08646915564934413 7.380856155318075e-05 [0.24268386]
# Nº neurônios: 1800
#
# 300/300 [==============================] - 6s 18ms/step
# 700/700 [==============================] - 0s 123us/step
# 0.08389297783374787 0.0002306942333234474 [0.24227704]
# Nº neurônios: 1900
#
# 300/300 [==============================] - 2s 7ms/step
# 700/700 [==============================] - 0s 120us/step
# 0.08659118602673213 0.0032126446666994263 [0.24080219]
# Nº neurônios: 2000
#
# 300/300 [==============================] - 2s 7ms/step
# 700/700 [==============================] - 0s 106us/step
# 0.08294653231898944 0.0001954105621137257 [0.23827538]

# %%
res_mse=np.asarray(res_mse)
res_mae=np.asarray(res_mae)
neur=np.asarray(neur)

print(res_mae,res_mse)

plt.plot(neur,res_mse)
plt.title('mse')
plt.ylabel('mse')
plt.xlabel('Número de neurônios')
plt.show()

plt.plot(neur,res_mae)
plt.title('mae')
plt.ylabel('mae')
plt.xlabel('Número de neurônios')
plt.show()
# Out:
# [[0.31252841]
#  [0.31938489]
#  [0.30442556]
#  [0.31083441]
#  [0.326384  ]
#  [0.33945305]
#  [0.3068811 ]
#  [0.28562733]
#  [0.27707865]
#  [0.33701709]
#  [0.25775383]
#  [0.30380098]
#  [0.27172361]
#  [0.2943269 ]
#  [0.30859179]
#  [0.26696456]
#  [0.26968337]
#  [0.2754043 ]
#  [0.26638969]
#  [0.26318796]
#  [0.26116142]
#  [0.2509419 ]
#  [0.25895321]
#  [0.26122364]
#  [0.25580338]
#  [0.26125569]
#  [0.24245133]
#  [0.25265056]
#  [0.23891012]
#  [0.24534609]
#  [0.24268386]
#  [0.24227704]
#  [0.24080219]
#  [0.23827538]] [0.12649642 0.13907795 0.13067994 0.13871369 0.15320818 0.16080787
#  0.13889703 0.11899971 0.11386485 0.17015762 0.1038312  0.13579312
#  0.10667976 0.13115174 0.13597915 0.10638907 0.1060757  0.10883938
#  0.10297633 0.10150104 0.09890011 0.09094056 0.0961128  0.0977192
#  0.09677322 0.09607728 0.08766484 0.08922754 0.08272119 0.08724497
#  0.08646916 0.08389298 0.08659119 0.08294653]
