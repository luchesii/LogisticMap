# %%
import numpy as np
import random

r = 4
x0=0.1

n=1000 #número de dados no dataset

lenght=10 #tamanho da sequencia

file = open('lstm_xn+10_data1000_x0.1_r4_l10.csv','w+')

# %%
for i in range(200):
    x1=x0*r*(1-x0)
    x0=x1

x=[]
for i in range(n*10):
    x1=x0*r*(1-x0)
    x0=x1
    x.append(x1)
    
x=np.asarray(x)

ind=random.sample(range(x.shape[0]-lenght**2-9), n)

print(ind)


for i in range(n):
    for j in range(lenght):
        file.write('{}'.format(x[ind[i]+j]))
        file.write(',')
    file.write('{}'.format(x[ind[i]+lenght+9]))
    file.write('\n')
    
file.close()
# Out:
# [5276, 381, 8984, 8505, 2077, 8072, 806, 5351, 5647, 5729, 5671, 9165, 853, 5404, 882, 1105, 4605, 467, 1324, 5643, 2226, 7455, 6681, 9215, 8794, 294, 8088, 8099, 5934, 9515, 1054, 5038, 8422, 3548, 4202, 777, 2781, 6187, 7763, 7015, 7508, 8001, 6841, 2442, 7743, 3038, 4619, 5797, 9144, 867, 8059, 3384, 153, 2533, 9486, 6438, 693, 4792, 3503, 8648, 3188, 3071, 5266, 9246, 7138, 9810, 1543, 4193, 2108, 4989, 9258, 3908, 4356, 8803, 8695, 1211, 7891, 4543, 5455, 9795, 6707, 94, 5114, 426, 3052, 3118, 5259, 3374, 5155, 4941, 4978, 2259, 194, 5277, 9756, 1722, 459, 748, 3528, 1018, 3121, 5963, 2293, 62, 9092, 3965, 7637, 5278, 1523, 4010, 3228, 1640, 972, 813, 5757, 1107, 169, 5993, 1547, 7214, 841, 32, 8006, 9820, 721, 2130, 1466, 9740, 5176, 7250, 5100, 4940, 425, 3937, 8870, 6861, 9264, 2005, 2511, 5903, 7913, 8952, 2334, 5009, 4254, 6886, 8987, 9288, 3294, 1308, 830, 267, 3935, 6274, 5640, 2135, 4682, 7916, 221, 5836, 596, 4051, 6160, 4380, 4087, 4665, 9653, 1805, 6909, 4863, 2328, 7
# ...
