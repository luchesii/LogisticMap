# %%
import numpy as np
import keras
from keras.models import Sequential
import tensorflow as tf
import torch
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
dataset=np.loadtxt("lstm_in10_out10_d100_l10_x0.1_r4.csv", delimiter=",")


i_lenght=10
o_lenght=10
data=dataset[:,0:i_lenght].copy()
label=dataset[:,i_lenght:].copy()

dtrain,dtest,ltrain,ltest=train_test_split(data,label,train_size=0.7,random_state=1)


'''
dtrain=tf.convert_to_tensor(dtrain0)
dtest=tf.convert_to_tensor(dtest0)
ltest=tf.convert_to_tensor(ltest0)
ltrain=tf.convert_to_tensor(ltrain0)'''
# Out:
# /home/ana/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# '\ndtrain=tf.convert_to_tensor(dtrain0)\ndtest=tf.convert_to_tensor(dtest0)\nltest=tf.convert_to_tensor(ltest0)\nltrain=tf.convert_to_tensor(ltrain0)'

# %%
results = []

n = 5
while n<=1000:
    
    model = Sequential()
    model.add(keras.layers.LSTM(n, activation='relu', input_shape=(i_lenght, 1)))
    model.add(keras.layers.Dense(o_lenght)) 

    model.compile(optimizer=keras.optimizers.Adam(),loss='mean_squared_error')
    
    dtrain = dtrain.reshape((dtrain.shape[0],i_lenght,1))
    dtest = dtest.reshape((dtest.shape[0],o_lenght,1))
    
    history = model.fit(dtrain, ltrain, epochs=250,verbose=0)
    
    msetrain = model.evaluate(dtrain, ltrain)
    mse = model.evaluate(dtest, ltest)
    print(mse)
    
    line = np.empty((3))
    line = n, msetrain, mse
    
    results.append(line)
    
    print('n:',n,'\n mse:',mse)
    
    plt.plot(history.history['loss'])
    plt.title('Data:100, input_lenght=10, output_lenght=10 n=%d' %n)
    plt.ylabel('mse treinamento')
    plt.xlabel('epoch')
    plt.show()
    
    prediction = model.predict(dtest[0,:].reshape((1,o_lenght,1)))
    
    
    plt.plot(range(i_lenght,i_lenght+o_lenght),ltest[0,:],'k',label="expected")
    plt.plot(range(i_lenght,i_lenght+o_lenght),prediction.T,'r', label="predicted")
    lo,hi = plt.ylim()
    #plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:')
    plt.legend(loc=(0.61,1.1),fontsize='x-small')
    plt.show()
    
    if n < 50:
        n = n+5
    elif n < 100:
        n = n+10
    elif n < 1000:
        n = n+100
    else:
        n = n+1000
        
print(results)
# Out:
# 70/70 [==============================] - 1s 9ms/step
# 30/30 [==============================] - 0s 546us/step
# 0.12318495661020279
# n: 5
#  mse: 0.12318495661020279
# 70/70 [==============================] - 1s 10ms/step
# 30/30 [==============================] - 0s 76us/step
# 0.12017952650785446
# n: 10
#  mse: 0.12017952650785446
# 70/70 [==============================] - 1s 11ms/step
# 30/30 [==============================] - 0s 104us/step
# 0.12447579205036163
# n: 15
#  mse: 0.12447579205036163
# 70/70 [==============================] - 1s 15ms/step
# 30/30 [==============================] - 0s 95us/step
# 0.12233410775661469
# n: 20
#  mse: 0.12233410775661469
# 70/70 [==============================] - 1s 13ms/step
# 30/30 [==============================] - 0s 118us/step
# 0.12651312351226807
# n: 25
#  mse: 0.12651312351226807
# 70/70 [==============================] - 1s 12ms/step
# 30/30 [==============================] - 0s 251us/step
# 0.1241314709186554
# n: 30
#  mse: 0.1241314709186554
# 70/70 [==============================] - 1s 13ms/step
# 30/30 [==============================] - 0s 289us/step
# 0.1220526248216629
# n: 35
#  mse: 0.1220526248216629
# 70/70 [==============================] - 1s 14ms/step
# 30/30 [==============================] - 0s 99us/step
# 0.12408079952001572
# n: 40
#  mse: 0.12408079952001572
# 70/70 [==============================] - 1s 15ms/step
# 30/30 [==============================] - 0s 100us/step
# 0.12365274131298065
# n: 45
#  mse: 0.12365274131298065
# 70/70 [==============================] - 1s 16ms/step
# 30/30 [==============================] - 0s 89us/step
# 0.12257013469934464
# n: 50
#  mse: 0.12257013469934464
# 70/70 [==============================] - 1s 16ms/step
# 30/30 [==============================] - 0s 327us/step
# 0.126107320189476
# n: 60
#  mse: 0.126107320189476
# 70/70 [==============================] - 1s 16ms/step
# 30/30 [==============================] - 0s 122us/step
# 0.1275695413351059
# n: 70
#  mse: 0.1275695413351059
# 70/70 [==============================] - 2s 23ms/step
# 30/30 [==============================] - 0s 85us/step
# 0.12272843718528748
# n: 80
#  mse: 0.12272843718528748
# 70/70 [==============================] - 1s 18ms/step
# 30/30 [==============================] - 0s 109us/step
# 0.1224152147769928
# n: 90
#  mse: 0.1224152147769928
# 70/70 [==============================] - 1s 19ms/step
# 30/30 [==============================] - 0s 207us/step
# 0.12603576481342316
# n: 100
#  mse: 0.12603576481342316
# 70/70 [==============================] - 1s 19ms/step
# 30/30 [==============================] - 0s 174us/step
# 0.13183951377868652
# n: 200
#  mse: 0.13183951377868652
# 70/70 [==============================] - 1s 20ms/step
# 30/30 [==============================] - 0s 279us/step
# 0.14270898699760437
# n: 300
#  mse: 0.14270898699760437
# 70/70 [==============================] - 2s 30ms/step
# 30/30 [==============================] - 0s 583us/step
# 0.14358456432819366
# n: 400
#  mse: 0.14358456432819366
# 70/70 [==============================] - 2s 24ms/step
# 30/30 [==============================] - 0s 237us/step
# 0.14359788596630096
# n: 500
#  mse: 0.14359788596630096
# 70/70 [==============================] - 2s 23ms/step
# 30/30 [==============================] - 0s 678us/step
# 0.14106573164463043
# n: 600
#  mse: 0.14106573164463043
# 70/70 [==============================] - 1s 19ms/step
# 30/30 [==============================] - 0s 755us/step
# 0.14227701723575592
# n: 700
#  mse: 0.14227701723575592
# 70/70 [==============================] - 1s 20ms/step
# 30/30 [==============================] - 0s 703us/step
# 0.13956624269485474
# n: 800
#  mse: 0.13956624269485474
# 70/70 [==============================] - 2s 22ms/step
# 30/30 [==============================] - 0s 773us/step
# 0.14779981970787048
# n: 900
#  mse: 0.14779981970787048
# 70/70 [==============================] - 2s 30ms/step
# 30/30 [==============================] - 0s 10ms/step
# 0.13876017928123474
# n: 1000
#  mse: 0.13876017928123474
# [(5, 0.11967356375285558, 0.12318495661020279), (10, 0.11466489008494786, 0.12017952650785446), (15, 0.11726380948509489, 0.12447579205036163), (20, 0.11865981327635901, 0.12233410775661469), (25, 0.11543126787458147, 0.12651312351226807), (30, 0.11167672127485276, 0.1241314709186554), (35, 0.11820969943489347, 0.1220526248216629), (40, 0.11712008523089545, 0.12408079952001572), (45, 0.11727067743028913, 0.12365274131298065), (50, 0.11120106556585857, 0.12257013469934464), (60, 0.1161570165838514, 0.126107320189476), (70, 0.11357028995241437, 0.1275695413351059), (80, 0.11199965498277119, 0.12272843718528748), (90, 0.11676972763878958, 0.1224152147769928), (100, 0.1154101774096489, 0.12603576481342316), (200, 0.11299524967159544, 0.13183951377868652), (300, 0.10601581803389958, 0.14270898699760437), (400, 0.10377655731780189, 0.14358456432819366), (500, 0.1017631328531674, 0.14359788596630096), (600, 0.10863673112222126, 0.14106573164463043), (700, 0.10466243496962956, 0.14227701723575592), (800, 0.106243711071355, 0.13956624269485474), (900, 0.10302828018154417, 0.14779981970787048), (1000, 0.10305671095848083, 0.13876017928123474)]

# %%
results = np.asarray(results)

results_c=results.copy()

plt.plot(results[:,0],results[:,1], 'k',label='train')
plt.title('Data:100, input_lenght=10, output_lenght=10')
plt.ylabel('mse ')
plt.xlabel('n')

plt.plot(results[:,0],results[:,2],'g',label='test')
plt.title('Data:100, input_lenght=10, output_lenght=10')
plt.ylabel('mse')
plt.xlabel('n')
          
          
plt.show()
