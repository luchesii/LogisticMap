# %%
import numpy as np
import keras
from keras.models import Sequential
import tensorflow as tf
import torch
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
dataset=np.loadtxt("lstm_in10_out10_d100_l10_x0.1_r4.csv", delimiter=",")


i_lenght=10
o_lenght=10
data=dataset[:,0:i_lenght].copy()
label=dataset[:,i_lenght:].copy()

dtrain,dtest,ltrain,ltest=train_test_split(data,label,train_size=0.7,random_state=1)


'''
dtrain=tf.convert_to_tensor(dtrain0)
dtest=tf.convert_to_tensor(dtest0)
ltest=tf.convert_to_tensor(ltest0)
ltrain=tf.convert_to_tensor(ltrain0)'''
# Out:
# /home/ana/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# '\ndtrain=tf.convert_to_tensor(dtrain0)\ndtest=tf.convert_to_tensor(dtest0)\nltest=tf.convert_to_tensor(ltest0)\nltrain=tf.convert_to_tensor(ltrain0)'

# %%
results = []

n = 5
while n<=1000:
    
    model = Sequential()
    model.add(keras.layers.LSTM(n, activation='relu', input_shape=(i_lenght, 1)))
    model.add(keras.layers.Dense(o_lenght)) 

    model.compile(optimizer=keras.optimizers.Adam(),loss='mean_squared_error')
    
    dtrain = dtrain.reshape((dtrain.shape[0],i_lenght,1))
    dtest = dtest.reshape((dtest.shape[0],o_lenght,1))
    
    history = model.fit(dtrain, ltrain, epochs=250,verbose=0)
    
    msetrain = model.evaluate(dtrain, ltrain)
    mse = model.evaluate(dtest, ltest)
    print(mse)
    
    line = np.empty((3))
    line = n, msetrain, mse
    
    results.append(line)
    
    print('n:',n,'\n mse:',mse)
    
    plt.plot(history.history['loss'])
    plt.title('Data:100, input_lenght=10, output_lenght=10 n=%d' %n)
    plt.ylabel('mse treinamento')
    plt.xlabel('epoch')
    plt.show()
    
    prediction = model.predict(dtest[0,:].reshape((1,o_lenght,1)))
    
    
    plt.plot(range(i_lenght,i_lenght+o_lenght),ltest[0,:],'k',label="expected")
    plt.plot(range(i_lenght,i_lenght+o_lenght),prediction.T,'r', label="predicted")
    lo,hi = plt.ylim()
    #plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:')
    plt.legend(loc=(0.61,1.1),fontsize='x-small')
    plt.show()
    
    if n < 50:
        n = n+5
    elif n < 100:
        n = n+10
    elif n < 1000:
        n = n+100
    else:
        n = n+1000
        
print(results)
# Out:
# WARNING:tensorflow:From /home/ana/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ana/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 70/70 [==============================] - 0s 6ms/step
# 30/30 [==============================] - 0s 641us/step
# 0.12377353012561798
# n: 5
#  mse: 0.12377353012561798
# 70/70 [==============================] - 0s 6ms/step
# 30/30 [==============================] - 0s 132us/step
# 0.12448291480541229
# n: 10
#  mse: 0.12448291480541229
# 70/70 [==============================] - 1s 13ms/step
# 30/30 [==============================] - 0s 4ms/step
# 0.12108870595693588
# n: 15
#  mse: 0.12108870595693588
# 70/70 [==============================] - 1s 13ms/step
# 30/30 [==============================] - 0s 3ms/step
# 0.1236344501376152
# n: 20
#  mse: 0.1236344501376152
# 70/70 [==============================] - 1s 9ms/step
# 30/30 [==============================] - 0s 278us/step
# 0.12200924754142761
# n: 25
#  mse: 0.12200924754142761
# 70/70 [==============================] - 1s 10ms/step
# 30/30 [==============================] - 0s 202us/step
# 0.1276712864637375
# n: 30
#  mse: 0.1276712864637375
# 70/70 [==============================] - 1s 10ms/step
# 30/30 [==============================] - 0s 434us/step
# 0.12306047976016998
# n: 35
#  mse: 0.12306047976016998
# 70/70 [==============================] - 1s 13ms/step
# 30/30 [==============================] - 0s 236us/step
# 0.1257348209619522
# n: 40
#  mse: 0.1257348209619522
# 70/70 [==============================] - 1s 14ms/step
# 30/30 [==============================] - 0s 276us/step
# 0.12344273179769516
# n: 45
#  mse: 0.12344273179769516
# 70/70 [==============================] - 1s 14ms/step
# 30/30 [==============================] - 0s 375us/step
# 0.12359511852264404
# n: 50
#  mse: 0.12359511852264404
# 70/70 [==============================] - 1s 19ms/step
# 30/30 [==============================] - 0s 314us/step
# 0.12598972022533417
# n: 60
#  mse: 0.12598972022533417
# 70/70 [==============================] - 2s 23ms/step
# 30/30 [==============================] - 0s 1ms/step
# 0.12712253630161285
# n: 70
#  mse: 0.12712253630161285
# 70/70 [==============================] - 1s 17ms/step
# 30/30 [==============================] - 0s 386us/step
# 0.12691324949264526
# n: 80
#  mse: 0.12691324949264526
# 70/70 [==============================] - 2s 22ms/step
# 30/30 [==============================] - 0s 402us/step
# 0.1296723484992981
# n: 90
#  mse: 0.1296723484992981
# 70/70 [==============================] - 1s 20ms/step
# 30/30 [==============================] - 0s 868us/step
# 0.13255935907363892
# n: 100
#  mse: 0.13255935907363892
# 70/70 [==============================] - 2s 26ms/step
# 30/30 [==============================] - 0s 266us/step
# 0.14112652838230133
# n: 200
#  mse: 0.14112652838230133
# 70/70 [==============================] - 2s 30ms/step
# 30/30 [==============================] - 0s 1ms/step
# 0.13805195689201355
# n: 300
#  mse: 0.13805195689201355
# 70/70 [==============================] - 2s 28ms/step
# 30/30 [==============================] - 0s 547us/step
# 0.13212166726589203
# n: 400
#  mse: 0.13212166726589203
# 70/70 [==============================] - 2s 32ms/step
# 30/30 [==============================] - 0s 1ms/step
# 0.1361854523420334
# n: 500
#  mse: 0.1361854523420334
# 70/70 [==============================] - 2s 28ms/step
# 30/30 [==============================] - 0s 1ms/step
# 0.14880512654781342
# n: 600
#  mse: 0.14880512654781342
# 70/70 [==============================] - 2s 31ms/step
# 30/30 [==============================] - 0s 1ms/step
# 0.137443408370018
# n: 700
#  mse: 0.137443408370018
# 70/70 [==============================] - 2s 29ms/step
# 30/30 [==============================] - 0s 2ms/step
# 0.13773737847805023
# n: 800
#  mse: 0.13773737847805023
# 70/70 [==============================] - 3s 45ms/step
# 30/30 [==============================] - 0s 1ms/step
# 0.1436118185520172
# n: 900
#  mse: 0.1436118185520172
# 70/70 [==============================] - 2s 32ms/step
# 30/30 [==============================] - 0s 4ms/step
# 0.14133548736572266
# n: 1000
#  mse: 0.14133548736572266
# [(5, 0.12005490469081061, 0.12377353012561798), (10, 0.11576652015958513, 0.12448291480541229), (15, 0.11835302306073052, 0.12108870595693588), (20, 0.11845880895853042, 0.1236344501376152), (25, 0.117176853120327, 0.12200924754142761), (30, 0.1164422475865909, 0.1276712864637375), (35, 0.11639801945005145, 0.12306047976016998), (40, 0.11433320790529251, 0.1257348209619522), (45, 0.1169239240033286, 0.12344273179769516), (50, 0.11469063141516277, 0.12359511852264404), (60, 0.11604096889495849, 0.12598972022533417), (70, 0.11001399351017815, 0.12712253630161285), (80, 0.11067636460065841, 0.12691324949264526), (90, 0.10845262834003994, 0.1296723484992981), (100, 0.112188549552645, 0.13255935907363892), (200, 0.10543258211442402, 0.14112652838230133), (300, 0.10935903298003333, 0.13805195689201355), (400, 0.10732128598860331, 0.13212166726589203), (500, 0.10588614195585251, 0.1361854523420334), (600, 0.10297815821000508, 0.14880512654781342), (700, 0.10615861415863037, 0.137443408370018), (800, 0.10161563966955457, 0.13773737847805023), (900, 0.098687273476805, 0.1436118185520172), (1000, 0.10154318383761815, 0.14133548736572266)]

# %%
results = np.asarray(results)

print(results)
results_c=results.copy()

plt.plot(results[:,0],results[:,1], 'k',label='train')
plt.title('Data:100, input_lenght=10, output_lenght=10')
plt.ylabel('mse ')
plt.xlabel('n')

plt.plot(results[:,0],results[:,2],'g',label='test')
plt.title('Data:100, input_lenght=10, output_lenght=10')
plt.ylabel('mse')
plt.xlabel('n')
          
          
plt.show()
# Out:
# [[5.00000000e+00 1.20054905e-01 1.23773530e-01]
#  [1.00000000e+01 1.15766520e-01 1.24482915e-01]
#  [1.50000000e+01 1.18353023e-01 1.21088706e-01]
#  [2.00000000e+01 1.18458809e-01 1.23634450e-01]
#  [2.50000000e+01 1.17176853e-01 1.22009248e-01]
#  [3.00000000e+01 1.16442248e-01 1.27671286e-01]
#  [3.50000000e+01 1.16398019e-01 1.23060480e-01]
#  [4.00000000e+01 1.14333208e-01 1.25734821e-01]
#  [4.50000000e+01 1.16923924e-01 1.23442732e-01]
#  [5.00000000e+01 1.14690631e-01 1.23595119e-01]
#  [6.00000000e+01 1.16040969e-01 1.25989720e-01]
#  [7.00000000e+01 1.10013994e-01 1.27122536e-01]
#  [8.00000000e+01 1.10676365e-01 1.26913249e-01]
#  [9.00000000e+01 1.08452628e-01 1.29672348e-01]
#  [1.00000000e+02 1.12188550e-01 1.32559359e-01]
#  [2.00000000e+02 1.05432582e-01 1.41126528e-01]
#  [3.00000000e+02 1.09359033e-01 1.38051957e-01]
#  [4.00000000e+02 1.07321286e-01 1.32121667e-01]
#  [5.00000000e+02 1.05886142e-01 1.36185452e-01]
#  [6.00000000e+02 1.02978158e-01 1.48805127e-01]
#  [7.00000000e+02 1.06158614e-01 1.37443408e-01]
#  [8.00000000e+02 1.01615640e-01 1.37737378e-01]
#  [9.00000000e+02 9.86872735e-02 1.43611819e-01]
#  [1.00000000e+03 1.01543184e-01 1.41335487e-01]]
