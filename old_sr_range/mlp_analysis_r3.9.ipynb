# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
table1 = np.loadtxt("mlp_x1_r3.9_minstable.csv", delimiter=",")
table2 = np.loadtxt("mlp_x2_r3.9_minstable.csv", delimiter=",")
table3 = np.loadtxt("mlp_x3_r3.9_minstable.csv", delimiter=",")
table4 = np.loadtxt("mlp_x4_r3.9_minstable.csv", delimiter=",")
print("l",table1.shape)
# Out:
# l (54, 4)

# %%
for i in range(1,5):
    
    if i ==1: 
        N = table1[:,0]
        MAE = table1[:,1]
        MSE = table1[:,2]
        RMSE = table1[:,3]
    elif i ==2: 
        N = table2[:,0]
        MAE = table2[:,1]
        MSE = table2[:,2]
        RMSE = table2[:,3]
    elif i ==3: 
        N = table3[:,0]
        MAE = table3[:,1]
        MSE = table3[:,2]
        RMSE = table3[:,3]
    elif i ==4: 
        N = table4[:,0]
        MAE = table4[:,1]
        MSE = table4[:,2]
        RMSE = table4[:,3]
        
    print(N.shape,MAE.shape,MSE.shape)
    plt.plot(N,MSE)
    plt.title('MSE xn+%d' %(i))
    plt.ylabel('mse')
    plt.xlabel('Number of neurons')
    plt.show()
    
    plt.plot(N,RMSE)
    plt.title('RMSE xn+%d' %(i))
    plt.ylabel('rmse')
    plt.xlabel('Number of neurons')
    plt.show()
    
    plt.plot(N,MAE)
    plt.title('MAE xn+%d' %(i))
    plt.ylabel('mae')
    plt.xlabel('Number of neurons')
    plt.show()
    
    print('MSE min:',N[np.argmin(MSE)],MSE[np.argmin(MSE)])
    print('MAE min:',N[np.argmin(MAE)],MAE[np.argmin(MAE)])
    print('RMSE min:',N[np.argmin(RMSE)],RMSE[np.argmin(RMSE)])
# Out:
# (54,) (54,) (54,)
# MSE min: 1200.0 3.8732876115924836e-07
# MAE min: 2400.0 0.00044534138506451064
# RMSE min: 1200.0 0.000622357422354107
# (54,) (54,) (54,)
# MSE min: 2600.0 2.413024711737914e-06
# MAE min: 3500.0 0.001109322206897042
# RMSE min: 2600.0 0.0015533913582024053
# (54,) (54,) (54,)
# MSE min: 3900.0 0.002495217377319932
# MAE min: 3900.0 0.030726860991791748
# RMSE min: 3900.0 0.04995215087781438
# (54,) (54,) (54,)
# MSE min: 2900.0 0.021840961173176767
# MAE min: 3700.0 0.10443272722196129
# RMSE min: 2900.0 0.1477868775405204

# %%
t1 = np.loadtxt("mlp_x1_r3.9_x0_ae_se.csv", delimiter=",")
t2 = np.loadtxt("mlp_x2_r3.9_x0_ae_se.csv", delimiter=",")
t3 = np.loadtxt("mlp_x3_r3.9_x0_ae_se.csv", delimiter=",")
t4 = np.loadtxt("mlp_x4_r3.9_x0_ae_se.csv", delimiter=",")

# %%
for future in range(1,5):
    if future ==1: 
        x0 = t1[:,0]
        ae = t1[:,1]
        se = t1[:,2]
    elif future ==2: 
        x0 = t2[:,0]
        ae = t2[:,1]
        se = t2[:,2]
    elif future ==3: 
        x0 = t3[:,0]
        ae = t3[:,1]
        se = t3[:,2]
    elif future ==4: 
        x0 = t4[:,0]
        ae = t4[:,1]
        se = t4[:,2]
        
        ind = np.argsort(ae)
        for i in range(x0.shape[0]): 
            ii = ind[i]
            print(x0[ii],ae[ii])
        
        print("z")
        ind = np.argsort(se)
        for i in range(x0.shape[0]): 
            ii = ind[i]
            print(x0[ii],se[ii])
            
        print()
# Out:
# 0.97313142031883 0.0007729049259249665
# 0.8307598275614512 0.0009564033567591723
# 0.6594353522988203 0.0020497078157470927
# 0.5583361168613957 0.0022253874402599627
# 0.9418024323755667 0.002466708408085938
# 0.9426990631220078 0.0037439350969221685
# 0.9565068652091748 0.0041923442700332325
# 0.42004917875090314 0.0046877986715146425
# 0.4781400736811323 0.005690579815486263
# 0.27914397076549724 0.008847615545394816
# 0.9699606034478353 0.00929332911648073
# 0.15420410349204508 0.0096186592775791
# 0.6307212585182027 0.011653444901735699
# 0.40700169539382736 0.012883076863083709
# 0.19039295334310674 0.01334547037647027
# 0.09652691950810835 0.013711104559217618
# 0.4985762300957145 0.01588722470066306
# 0.217963915948386 0.01993549024629826
# 0.660551863148297 0.021987350508207548
# 0.26435522916825016 0.0248077142512082
# 0.3877766207911555 0.02806741576239563
# 0.9590667855336026 0.031967496434703147
# 0.6357843739539152 0.03309666476420492
# 0.4604688404811891 0.033127179432415166
# 0.4316757994460612 0.04055475180866863
# 0.954098339360775 0.04088686793929169
# 0.3893217741585796 0.050337340564246325
# 0.4733409860313093 0.06327014047874896
# 0.911830899081445 0.06479429227878075
# 0.6793146144919185 0.06955180652347287
# 0.6213549024220787 0.07810237025158945
# 0.6046774561543994 0.08472852187703339
# 0.12116989230567193 0.09117798806326782
# 0.9147592413486111 0.094721782028938
# 0.16250056126242876 0.10253387269000747
# 0.9668008030297528 0.1184300623523184
# 0.8287676867933779 0.12779315690862986
# 0.8941667986878361 0.12995235261740423
# 0.9749762692375304 0.13334377107176387
# 0.7005371139275068 0.14669623795243225
# 0.8781530141035017 0.16080296932594984
# 0.9461582588545935 0.16312849333684873
# 0.18371025977615535 0.17295002019508282
# 0.9748477925315415 0.1743396613460204
# 0.498948863902323 0.19090174899395743
# 0.10148268968794455 0.2221612188308515
# 0.32856620209179577 0.2334880341232971
# 0.6162262817046072 0.2373834217312245
# 0.26428328933618694 0.24226628424116314
# 0.43995984865978754 0.2762682355726866
# 0.47688423673716707 0.28420837609854044
# 0.10323692590677627 0.30938489168207056
# 0.8687209470552758 0.3259212511466274
# 0.8753732994060924 0.3265825439847796
# z
# 0.97313142031883 5.97382024519078e-07
# 0.8307598275614512 9.147073808202126e-07
# 0.6594353522988203 4.201302129934718e-06
# 0.5583361168613957 4.952349259266789e-06
# 0.9418024323755667 6.084650370521863e-06
# 0.9426990631220078 1.4017050009965607e-05
# 0.9565068652091748 1.7575750478480477e-05
# 0.42004917875090314 2.1975456384654446e-05
# 0.4781400736811323 3.2382698636419674e-05
# 0.27914397076549724 7.8280300839112e-05
# 0.9699606034478353 8.636596606722852e-05
# 0.15420410349204508 9.25186062981585e-05
# 0.6307212585182027 0.00013580277807778975
# 0.40700169539382736 0.00016597366946012279
# 0.19039295334310674 0.00017810157956924552
# 0.09652691950810835 0.00018799438823379817
# 0.4985762300957145 0.00025240390868935846
# 0.217963915948386 0.00039742377136025306
# 0.660551863148297 0.0004834435823707747
# 0.26435522916825016 0.0006154226863695985
# 0.3877766207911555 0.0007877798275791747
# 0.9590667855336026 0.0010219208283027584
# 0.6357843739539152 0.0010953892185141636
# 0.4604688404811891 0.0010974100171474304
# 0.4316757994460612 0.0016446878942627118
# 0.954098339360775 0.0016717359698850789
# 0.3893217741585796 0.0025338478550809185
# 0.4733409860313093 0.0040031106762006274
# 0.911830899081445 0.004198300311908067
# 0.6793146144919185 0.0048374537906786036
# 0.6213549024220787 0.006099980238916365
# 0.6046774561543994 0.007178922419466926
# 0.12116989230567193 0.00831342550726541
# 0.9147592413486111 0.008972215990737642
# 0.16250056126242876 0.010513195048810658
# 0.9668008030297528 0.014025679668774023
# 0.8287676867933779 0.01633109095267369
# 0.8941667986878361 0.01688761395079817
# 0.9749762692375304 0.01778056128363897
# 0.7005371139275068 0.021519786229396626
# 0.8781530141035017 0.025857594944042366
# 0.9461582588545935 0.0266109053383503
# 0.18371025977615535 0.029911709485479554
# 0.9748477925315415 0.030394317518245083
# 0.498948863902323 0.036443477768951925
# 0.10148268968794455 0.049355607152409484
# 0.32856620209179577 0.054516662078761956
# 0.6162262817046072 0.056350888912824394
# 0.26428328933618694 0.05869295248002005
# 0.43995984865978754 0.07632413798644545
# 0.47688423673716707 0.08077440104456941
# 0.10323692590677627 0.09571901120112654
# 0.8687209470552758 0.10622466194898297
# 0.8753732994060924 0.10665615803557049

# %%
cont = np.zeros((4))

for i in range(ae.shape[0]):
   
    if ae[i]<0.001 and ae[i]>0.0001:
        cont[3]+=1
    elif ae[i]<0.01 and ae[i]>0.001:
        cont[2]+=1
    elif ae[i]<0.1 and ae[i]>0.01:
        cont[1]+=1
    elif ae[i]<1 and ae[i]>0.1:
        cont[0]+=1

print(cont/ae.shape[0])

cont = np.zeros((7))

for i in range(ae.shape[0]):
    if se[i]<0.000001 and se[i]>0.0000001:
        cont[6]+=1
    elif se[i]<0.00001 and se[i]>0.000001:
        cont[5]+=1
    elif se[i]<0.0001 and se[i]>0.00001:
        cont[4]+=1
    elif se[i]<0.001 and se[i]>0.0001:
        cont[3]+=1
    elif se[i]<0.01 and se[i]>0.001:
        cont[2]+=1
    elif se[i]<0.1 and se[i]>0.01:
        cont[1]+=1
    elif se[i]<1 and se[i]>0.1:
        cont[0]+=1

print(cont/se.shape[0])
# Out:
# [0.37037037 0.40740741 0.18518519 0.03703704]
# [0.03703704 0.33333333 0.24074074 0.16666667 0.12962963 0.05555556
#  0.03703704]
